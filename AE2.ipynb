# %%
import csv

# Empty list to store data
csv_list = []  

while True:
    file_name = input("Enter the CSV file name or enter 'q' to quit the program: ")

    # If input is 'q', exit the program
    if file_name.lower() == 'q':  
        print("Exiting the program.")
        # Exit loop
        break  

    try:
        # Open the CSV file
        with open(file_name, 'r', encoding='UTF-8') as csv_file:
            csv_reader = csv.reader(csv_file)
            # Clear csv_list before storing new data in each opening
            csv_list.clear()
            
            # Read and store data using a for loop
            for row in csv_reader:
                # Append each row to the list
                csv_list.append(row)  
            
        print("CSV file loaded successfully.")
        # Exit loop after successfully reading the file
        break  

    # Allow user to try again by showing error
    except FileNotFoundError as e:
        print(f"File does not exist: {e}")
# Out:
# Enter the CSV file name or enter 'q' to quit the program:  credit_card_customers.csv
# CSV file loaded successfully.

# %%
import csv

# Empty list to store data
csv_list = []  

while True:
    file_name = input("Enter the CSV file name or enter 'q' to quit the program: ")

    # If input is 'q', exit the program
    if file_name.lower() == 'q':  
        print("Exiting the program.")
        # Exit loop
        break  

    try:
        # Open the CSV file
        with open(file_name, 'r', encoding='UTF-8') as csv_file:
            csv_reader = csv.reader(csv_file)
            # Clear csv_list before storing new data in each opening
            csv_list.clear()
            
            # Read and store data using a for loop
            for row in csv_reader:
                # Append each row to the list
                csv_list.append(row)  
            
        print("CSV file loaded successfully.")
        # Exit loop after successfully reading the file
        break  

    # Allow user to try again by showing error
    except FileNotFoundError as e:
        print(f"File does not exist: {e}")
# Out:
# Enter the CSV file name or enter 'q' to quit the program:  credit_card_customers.csv
# CSV file loaded successfully.

# %%
import csv

# Empty list to store data
csv_list = []  

while True:
    file_name = input("Enter the CSV file name or enter 'q' to quit the program: ")

    # If input is 'q', exit the program
    if file_name.lower() == 'q':  
        print("Exiting the program.")
        # Exit loop
        break  

    try:
        # Open the CSV file
        with open(file_name, 'r', encoding='UTF-8') as csv_file:
            csv_reader = csv.reader(csv_file)
            # Clear csv_list before storing new data in each opening
            csv_list.clear()
            
            # Read and store data using a for loop
            for row in csv_reader:
                # Append each row to the list
                csv_list.append(row)  
            
        print("CSV file loaded successfully.")
        # Exit loop after successfully reading the file
        break  

    # Allow user to try again by showing error
    except FileNotFoundError as e:
        print(f"File does not exist: {e}")
# Out:
# Enter the CSV file name or enter 'q' to quit the program:  credit_card_customers.csv
# CSV file loaded successfully.

# %%
#Retrieve the client number, gender, education level, and income of customers based on their card category. 

import csv

#create an empty list
card_catergory = []

#ask user for the card catergoy 
category_input = input("Enter the card catergory of the customer (Blue/Planitum/Gold/Silver): ")

for row in csv_list:
    if row[15] == category_input:
        card_catergory.append({
            'Client_Num': row[0],         
            'Gender' : row[2],
            'Education_Level' : row[4],  
            'Income' : row[13]
        })

if card_catergory:
    for item in card_catergory:
        print(item)

else:
    print("Error")
# Out:
# Enter the card catergory of the customer (Blue/Planitum/Gold/Silver):  Platinum
# {'Client_Num': '708103608', 'Gender': 'F', 'Education_Level': 'Graduate', 'Income': '223196'}
# {'Client_Num': '708163758', 'Gender': 'M', 'Education_Level': 'Graduate', 'Income': '123809'}
# {'Client_Num': '708654933', 'Gender': 'F', 'Education_Level': 'High School', 'Income': '20322'}
# {'Client_Num': '708873183', 'Gender': 'M', 'Education_Level': 'Uneducated', 'Income': '214196'}
# {'Client_Num': '708942408', 'Gender': 'F', 'Education_Level': 'Uneducated', 'Income': '237248'}
# {'Client_Num': '709066983', 'Gender': 'F', 'Education_Level': 'Uneducated', 'Income': '206846'}
# {'Client_Num': '709094358', 'Gender': 'M', 'Education_Level': 'Uneducated', 'Income': '236628'}
# {'Client_Num': '709269708', 'Gender': 'M', 'Education_Level': 'Graduate', 'Income': '102442'}
# {'Client_Num': '709319658', 'Gender': 'M', 'Education_Level': 'High School', 'Income': '106278'}
# {'Client_Num': '709814883', 'Gender': 'F', 'Education_Level': 'Graduate', 'Income': '215862'}
# {'Client_Num': '709969758', 'Gender': 'M', 'Education_Level': 'Graduate', 'Income': '147447'}
# {'Client_Num': '710232483', 'Gender': 'F', 'Education_Level': 'High School', 'Income': '237124'}
# {'Client_Num': '710362233', 'Gender': 'F', 'Education_Level': 'Graduate', 'Income': '145292'}
# {'Client_Num': '710667708', 'Gender': 'M', 'Education_Level': 'Post-Graduate', 'Income': '149441'}
# {'Client_Num': '710699283', 'Gender': 'F', 'Education_Level': 'Unknown', 'Income': '174955'}
# {'Client_Num': '711010683', 'Gender': 'M', 'Education_Level': 'Graduate', 'Income': '122187'}
# {'Client_Num': '711364233', 'Gender': 'M', 'Education_Level': 'Graduate', 'Income': '117221'}
# {'Client_Num': '711398433', 'Gender': 'F', 'Education_Level': 'Uneducated', 'Income': '236601'}
# {'Client_Num': '711523533', 'Gender': 'M', 'Education_Level': 'High School', 'Income': '184323'}
# {'Client_Num': '711720408', 'Gender': 'M', 'Education_Level': 'High School', 'Income': '206552'}
# {'Client_Num': '712438308', 'Gender': 'M', 'Education_Level': 'Graduate', 'Income': '236211'}
# {'Client_Num': '712503408', 'Gender': 'F', 'Education_Level': 'Graduate', 'Income': '238789'}
# {'Client_Num': '713398158', 'Gender': 'F', 'Education_Level': 'High School', 'Income': '193843'}
# {'Client_Num': '713870958', 'Gender': 'M', 'Education_Level': 'Graduate', 'Income': '114091'}
# {'Client_Num': '713965683', 'Gender': 'M', 'Education_Level': 'High School', 'Income': '237836'}
# {'Client_Num': '714003483', 'Gender': 'F', 'Education_Level': 'Unknown', 'Income': '209290'}
# {'Client_Num': '714077583', 'Gender': 'M', 'Education_Level': 'Uneducated', 'Income': '77030'}
# {'Client_Num': '714190983', 'Gender': 'M', 'Education_Level': 'Post-Graduate', 'Income': '99124'}
# {'Client_Num': '714586458', 'Gender': 'F', 'Education_Level': 'High School', 'Income': '233849'}
# {'Client_Num': '714754533', 'Gender': 'M', 'Education_Level': 'Graduate', 'Income': '109992'}
# {'Client_Num': '714949758', 'Gender': 'F', 'Education_Level': 'Unknown', 'Income': '236089'}
# {'Client_Num': '715017858', 'Gender': 'M', 'Education_Level': 'High School', 'Income': '169380'}
# {'Client_Num': '715269483', 'Gender': 'M', 'Education_Level': 'Graduate', 'Income': '214158'}
# {'Client_Num': '715601808', 'Gender': 'F', 'Education_Level': 'Unknown', 'Income': '235908'}
# {'Client_Num': '715728108', 'Gender': 'M', 'Education_Level': 'Doctorate', 'Income': '164308'}
# {'Client_Num': '716004258', 'Gender': 'M', 'Education_Level': 'High School', 'Income': '239346'}
# {'Client_Num': '716430933', 'Gender': 'M', 'Education_Level': 'Uneducated', 'Income': '139445'}
# {'Client_Num': '716748483', 'Gender': 'F', 'Education_Level': 'Graduate', 'Income': '231268'}
# {'Client_Num': '716894658', 'Gender': 'F', 'Education_Level': 'Graduate', 'Income': '236967'}
# {'Client_Num': '717642633', 'Gender': 'M', 'Education_Level': 'Graduate', 'Income': '239676'}
# {'Client_Num': '717663033', 'Gender': 'M', 'Education_Level': 'Graduate', 'Income': '234318'}
# {'Client_Num': '717724233', 'Gender': 'F', 'Education_Level': 'High School', 'Income': '236409'}
# {'Client_Num': '717783483', 'Gender': 'F', 'Education_Level': 'Uneducated', 'Income': '237308'}
# {'Client_Num': '717788958', 'Gender': 'M', 'Education_Level': 'High School', 'Income': '234462'}
# {'Client_Num': '717991533', 'Gender': 'M', 'Education_Level': 'Graduate', 'Income': '234359'}
# {'Client_Num': '718071933', 'Gender': 'M', 'Education_Level': 'Uneducated', 'Income': '223710'}
# {'Client_Num': '718140783', 'Gender': 'F', 'Education_Level': 'Unknown', 'Income': '239791'}
# {'Client_Num': '719071158', 'Gender': 'F', 'Education_Level': 'Uneducated', 'Income': '44792'}
# {'Client_Num': '719420058', 'Gender': 'M', 'Education_Level': 'Graduate', 'Income': '235546'}
# {'Client_Num': '720515883', 'Gender': 'F', 'Education_Level': 'High School', 'Income': '234476'}
# {'Client_Num': '720608658', 'Gender': 'F', 'Education_Level': 'High School', 'Income': '236058'}
# {'Client_Num': '721220583', 'Gender': 'F', 'Education_Level': 'High School', 'Income': '238349'}
# {'Client_Num': '770848308', 'Gender': 'M', 'Education_Level': 'Unknown', 'Income': '116782'}
# {'Client_Num': '770926158', 'Gender': 'M', 'Education_Level': 'High School', 'Income': '144177'}
# {'Client_Num': '771217758', 'Gender': 'M', 'Education_Level': 'Uneducated', 'Income': '237133'}
# {'Client_Num': '771626283', 'Gender': 'F', 'Education_Level': 'Unknown', 'Income': '194993'}
# {'Client_Num': '778428108', 'Gender': 'F', 'Education_Level': 'Graduate', 'Income': '238388'}
# {'Client_Num': '779519058', 'Gender': 'F', 'Education_Level': 'High School', 'Income': '18635'}
# {'Client_Num': '780613758', 'Gender': 'F', 'Education_Level': 'Uneducated', 'Income': '237603'}
# {'Client_Num': '784868958', 'Gender': 'F', 'Education_Level': 'Unknown', 'Income': '146454'}
# {'Client_Num': '785038908', 'Gender': 'F', 'Education_Level': 'Unknown', 'Income': '237695'}
# {'Client_Num': '788779983', 'Gender': 'F', 'Education_Level': 'High School', 'Income': '234249'}
# {'Client_Num': '789074358', 'Gender': 'F', 'Education_Level': 'High School', 'Income': '237052'}
# {'Client_Num': '789539058', 'Gender': 'F', 'Education_Level': 'Graduate', 'Income': '237352'}
# {'Client_Num': '794494308', 'Gender': 'M', 'Education_Level': 'Graduate', 'Income': '141021'}
# {'Client_Num': '801036033', 'Gender': 'F', 'Education_Level': 'Graduate', 'Income': '239639'}
# {'Client_Num': '823848183', 'Gender': 'M', 'Education_Level': 'Post-Graduate', 'Income': '114299'}

# %%
#Retrieve the age, gender, income, and credit card category of customers based on their specific state of residence.

residency_state=[]

state = input("Enter customers specific state of residency () : ")

for row in csv_list:
    if row[6] == state:
        residency_state.append({
            'Customer_Age': row[1],
            'Gender': row[2],
            'Income': row[13],
            'Card_Category': row[15]
        })

if residency_state:
    for item in residency_state:
        print (item)

else: ('Error')
# Out:
# Enter customers specific state of residency () :  NJ
# {'Customer_Age': '62', 'Gender': 'F', 'Income': '5225', 'Card_Category': 'Blue'}
# {'Customer_Age': '32', 'Gender': 'F', 'Income': '14235', 'Card_Category': 'Blue'}
# {'Customer_Age': '48', 'Gender': 'M', 'Income': '86668', 'Card_Category': 'Blue'}
# {'Customer_Age': '53', 'Gender': 'F', 'Income': '223196', 'Card_Category': 'Platinum'}
# {'Customer_Age': '51', 'Gender': 'F', 'Income': '14975', 'Card_Category': 'Blue'}
# {'Customer_Age': '36', 'Gender': 'M', 'Income': '59416', 'Card_Category': 'Blue'}
# {'Customer_Age': '37', 'Gender': 'F', 'Income': '45476', 'Card_Category': 'Blue'}
# {'Customer_Age': '40', 'Gender': 'F', 'Income': '25835', 'Card_Category': 'Blue'}
# {'Customer_Age': '54', 'Gender': 'M', 'Income': '79516', 'Card_Category': 'Blue'}
# {'Customer_Age': '60', 'Gender': 'F', 'Income': '53022', 'Card_Category': 'Blue'}
# {'Customer_Age': '39', 'Gender': 'M', 'Income': '62192', 'Card_Category': 'Blue'}
# {'Customer_Age': '33', 'Gender': 'F', 'Income': '21500', 'Card_Category': 'Blue'}
# {'Customer_Age': '29', 'Gender': 'M', 'Income': '1250', 'Card_Category': 'Blue'}
# {'Customer_Age': '44', 'Gender': 'F', 'Income': '15092', 'Card_Category': 'Blue'}
# {'Customer_Age': '36', 'Gender': 'M', 'Income': '86574', 'Card_Category': 'Blue'}
# {'Customer_Age': '59', 'Gender': 'F', 'Income': '21659', 'Card_Category': 'Blue'}
# {'Customer_Age': '46', 'Gender': 'F', 'Income': '34013', 'Card_Category': 'Blue'}
# {'Customer_Age': '42', 'Gender': 'M', 'Income': '71834', 'Card_Category': 'Blue'}
# {'Customer_Age': '54', 'Gender': 'F', 'Income': '235349', 'Card_Category': 'Silver'}
# {'Customer_Age': '39', 'Gender': 'M', 'Income': '58122', 'Card_Category': 'Blue'}
# {'Customer_Age': '48', 'Gender': 'F', 'Income': '45372', 'Card_Category': 'Silver'}
# {'Customer_Age': '58', 'Gender': 'M', 'Income': '75578', 'Card_Category': 'Blue'}
# {'Customer_Age': '50', 'Gender': 'F', 'Income': '48968', 'Card_Category': 'Blue'}
# {'Customer_Age': '49', 'Gender': 'M', 'Income': '74928', 'Card_Category': 'Blue'}
# {'Customer_Age': '40', 'Gender': 'M', 'Income': '44044', 'Card_Category': 'Blue'}
# {'Customer_Age': '48', 'Gender': 'M', 'Income': '68693', 'Card_Category': 'Blue'}
# {'Customer_Age': '53', 'Gender': 'M', 'Income': '50213', 'Card_Category': 'Blue'}
# {'Customer_Age': '28', 'Gender': 'M', 'Income': '14975', 'Card_Category': 'Blue'}
# {'Customer_Age': '35', 'Gender': 'F', 'Income': '39538', 'Card_Category': 'Blue'}
# {'Customer_Age': '38', 'Gender': 'F', 'Income': '43330', 'Card_Category': 'Blue'}
# {'Customer_Age': '53', 'Gender': 'M', 'Income': '113458', 'Card_Category': 'Silver'}
# {'Customer_Age': '37', 'Gender': 'M', 'Income': '47266', 'Card_Category': 'Blue'}
# {'Customer_Age': '45', 'Gender': 'M', 'Income': '61806', 'Card_Category': 'Blue'}
# {'Customer_Age': '42', 'Gender': 'F', 'Income': '35361', 'Card_Category': 'Blue'}
# {'Customer_Age': '61', 'Gender': 'F', 'Income': '38205', 'Card_Category': 'Silver'}
# {'Customer_Age': '42', 'Gender': 'F', 'Income': '59307', 'Card_Category': 'Blue'}
# {'Customer_Age': '65', 'Gender': 'F', 'Income': '14975', 'Card_Category': 'Blue'}
# {'Customer_Age': '50', 'Gender': 'F', 'Income': '5525', 'Card_Category': 'Blue'}
# {'Customer_Age': '53', 'Gender': 'M', 'Income': '109128', 'Card_Category': 'Blue'}
# {'Customer_Age': '47', 'Gender': 'M', 'Income': '68004', 'Card_Category': 'Blue'}
# {'Customer_Age': '41', 'Gender': 'M', 'Income': '63667', 'Card_Category': 'Blue'}
# {'Customer_Age': '38', 'Gender': 'M', 'Income': '92816', 'Card_Category': 'Blue'}
# {'Customer_Age': '53', 'Gender': 'F', 'Income': '23073', 'Card_Category': 'Blue'}
# {'Customer_Age': '46', 'Gender': 'M', 'Income': '82618', 'Card_Category': 'Blue'}
# {'Customer_Age': '46', 'Gender': 'F', 'Income': '25795', 'Card_Category': 'Blue'}
# {'Customer_Age': '48', 'Gender': 'M', 'Income': '151385', 'Card_Category': 'Blue'}
# {'Customer_Age': '54', 'Gender': 'F', 'Income': '14975', 'Card_Category': 'Blue'}
# {'Customer_Age': '44', 'Gender': 'F', 'Income': '12484', 'Card_Category': 'Blue'}
# {'Customer_Age': '56', 'Gender': 'M', 'Income': '110205', 'Card_Category': 'Silver'}
# {'Customer_Age': '31', 'Gender': 'M', 'Income': '48135', 'Card_Category': 'Blue'}
# {'Customer_Age': '33', 'Gender': 'M', 'Income': '154909', 'Card_Category': 'Blue'}
# {'Customer_Age': '34', 'Gender': 'M', 'Income': '82748', 'Card_Category': 'Blue'}
# {'Customer_Age': '38', 'Gender': 'F', 'Income': '27728', 'Card_Category': 'Blue'}
# {'Customer_Age': '38', 'Gender': 'M', 'Income': '75375', 'Card_Category': 'Silver'}
# {'Customer_Age': '41', 'Gender': 'M', 'Income': '88654', 'Card_Category': 'Blue'}
# {'Customer_Age': '43', 'Gender': 'F', 'Income': '19471', 'Card_Category': 'Blue'}
# {'Customer_Age': '33', 'Gender': 'F', 'Income': '24410', 'Card_Category': 'Blue'}
# {'Customer_Age': '42', 'Gender': 'F', 'Income': '14548', 'Card_Category': 'Blue'}
# {'Customer_Age': '62', 'Gender': 'F', 'Income': '50156', 'Card_Category': 'Blue'}
# {'Customer_Age': '35', 'Gender': 'M', 'Income': '67052', 'Card_Category': 'Blue'}
# {'Customer_Age': '55', 'Gender': 'M', 'Income': '109942', 'Card_Category': 'Gold'}
# {'Customer_Age': '40', 'Gender': 'F', 'Income': '14975', 'Card_Category': 'Blue'}
# {'Customer_Age': '50', 'Gender': 'M', 'Income': '105206', 'Card_Category': 'Silver'}
# {'Customer_Age': '26', 'Gender': 'M', 'Income': '23994', 'Card_Category': 'Blue'}
# {'Customer_Age': '55', 'Gender': 'F', 'Income': '162342', 'Card_Category': 'Blue'}
# {'Customer_Age': '60', 'Gender': 'F', 'Income': '14975', 'Card_Category': 'Blue'}
# {'Customer_Age': '38', 'Gender': 'M', 'Income': '73510', 'Card_Category': 'Blue'}
# {'Customer_Age': '54', 'Gender': 'F', 'Income': '13763', 'Card_Category': 'Blue'}
# {'Customer_Age': '48', 'Gender': 'F', 'Income': '32977', 'Card_Category': 'Blue'}
# {'Customer_Age': '30', 'Gender': 'M', 'Income': '39969', 'Card_Category': 'Blue'}
# {'Customer_Age': '45', 'Gender': 'F', 'Income': '43234', 'Card_Category': 'Blue'}
# {'Customer_Age': '29', 'Gender': 'F', 'Income': '14975', 'Card_Category': 'Blue'}
# {'Customer_Age': '42', 'Gender': 'F', 'Income': '33541', 'Card_Category': 'Blue'}
# {'Customer_Age': '35', 'Gender': 'M', 'Income': '52805', 'Card_Category': 'Blue'}
# {'Customer_Age': '45', 'Gender': 'F', 'Income': '5525', 'Card_Category': 'Blue'}
# {'Customer_Age': '45', 'Gender': 'M', 'Income': '104586', 'Card_Category': 'Silver'}
# {'Customer_Age': '40', 'Gender': 'F', 'Income': '235039', 'Card_Category': 'Silver'}
# {'Customer_Age': '48', 'Gender': 'M', 'Income': '95965', 'Card_Category': 'Blue'}
# {'Customer_Age': '59', 'Gender': 'M', 'Income': '76846', 'Card_Category': 'Blue'}
# {'Customer_Age': '65', 'Gender': 'F', 'Income': '33675', 'Card_Category': 'Blue'}
# {'Customer_Age': '22', 'Gender': 'M', 'Income': '115680', 'Card_Category': 'Blue'}
# {'Customer_Age': '45', 'Gender': 'M', 'Income': '42835', 'Card_Category': 'Silver'}
# {'Customer_Age': '58', 'Gender': 'M', 'Income': '51851', 'Card_Category': 'Blue'}
# {'Customer_Age': '37', 'Gender': 'M', 'Income': '65446', 'Card_Category': 'Blue'}
# {'Customer_Age': '38', 'Gender': 'M', 'Income': '50489', 'Card_Category': 'Blue'}
# {'Customer_Age': '34', 'Gender': 'F', 'Income': '22914', 'Card_Category': 'Blue'}
# {'Customer_Age': '48', 'Gender': 'F', 'Income': '13322', 'Card_Category': 'Blue'}
# {'Customer_Age': '36', 'Gender': 'F', 'Income': '34330', 'Card_Category': 'Blue'}
# {'Customer_Age': '42', 'Gender': 'M', 'Income': '46629', 'Card_Category': 'Blue'}
# {'Customer_Age': '40', 'Gender': 'F', 'Income': '20741', 'Card_Category': 'Blue'}
# {'Customer_Age': '43', 'Gender': 'M', 'Income': '68115', 'Card_Category': 'Blue'}
# {'Customer_Age': '57', 'Gender': 'F', 'Income': '15955', 'Card_Category': 'Blue'}
# {'Customer_Age': '55', 'Gender': 'F', 'Income': '150731', 'Card_Category': 'Blue'}
# {'Customer_Age': '57', 'Gender': 'F', 'Income': '14975', 'Card_Category': 'Blue'}
# {'Customer_Age': '37', 'Gender': 'F', 'Income': '11597', 'Card_Category': 'Blue'}
# {'Customer_Age': '39', 'Gender': 'M', 'Income': '65104', 'Card_Category': 'Blue'}
# {'Customer_Age': '41', 'Gender': 'F', 'Income': '16687', 'Card_Category': 'Blue'}
# {'Customer_Age': '56', 'Gender': 'F', 'Income': '59341', 'Card_Category': 'Blue'}
# {'Customer_Age': '43', 'Gender': 'M', 'Income': '69714', 'Card_Category': 'Blue'}
# {'Customer_Age': '57', 'Gender': 'F', 'Income': '176141', 'Card_Category': 'Blue'}
# {'Customer_Age': '50', 'Gender': 'M', 'Income': '117226', 'Card_Category': 'Blue'}
# {'Customer_Age': '37', 'Gender': 'M', 'Income': '68415', 'Card_Category': 'Blue'}
# {'Customer_Age': '41', 'Gender': 'M', 'Income': '121796', 'Card_Category': 'Blue'}
# {'Customer_Age': '51', 'Gender': 'F', 'Income': '218777', 'Card_Category': 'Gold'}
# {'Customer_Age': '53', 'Gender': 'F', 'Income': '22514', 'Card_Category': 'Blue'}
# {'Customer_Age': '43', 'Gender': 'M', 'Income': '73199', 'Card_Category': 'Blue'}
# {'Customer_Age': '60', 'Gender': 'M', 'Income': '79755', 'Card_Category': 'Blue'}
# {'Customer_Age': '55', 'Gender': 'M', 'Income': '63909', 'Card_Category': 'Blue'}
# {'Customer_Age': '44', 'Gender': 'F', 'Income': '35673', 'Card_Category': 'Blue'}
# {'Customer_Age': '49', 'Gender': 'F', 'Income': '49631', 'Card_Category': 'Blue'}
# {'Customer_Age': '47', 'Gender': 'M', 'Income': '72644', 'Card_Category': 'Blue'}
# {'Customer_Age': '54', 'Gender': 'F', 'Income': '34379', 'Card_Category': 'Blue'}
# {'Customer_Age': '39', 'Gender': 'F', 'Income': '35480', 'Card_Category': 'Blue'}
# {'Customer_Age': '37', 'Gender': 'M', 'Income': '139871', 'Card_Category': 'Blue'}
# {'Customer_Age': '55', 'Gender': 'F', 'Income': '35844', 'Card_Category': 'Blue'}
# {'Customer_Age': '30', 'Gender': 'M', 'Income': '77774', 'Card_Category': 'Blue'}
# {'Customer_Age': '46', 'Gender': 'F', 'Income': '28932', 'Card_Category': 'Blue'}
# {'Customer_Age': '46', 'Gender': 'F', 'Income': '29350', 'Card_Category': 'Silver'}
# {'Customer_Age': '60', 'Gender': 'F', 'Income': '35881', 'Card_Category': 'Blue'}
# {'Customer_Age': '49', 'Gender': 'M', 'Income': '88133', 'Card_Category': 'Blue'}
# {'Customer_Age': '50', 'Gender': 'M', 'Income': '91988', 'Card_Category': 'Blue'}
# {'Customer_Age': '35', 'Gender': 'M', 'Income': '150458', 'Card_Category': 'Blue'}
# {'Customer_Age': '45', 'Gender': 'M', 'Income': '77929', 'Card_Category': 'Blue'}
# {'Customer_Age': '46', 'Gender': 'F', 'Income': '33941', 'Card_Category': 'Blue'}
# {'Customer_Age': '56', 'Gender': 'M', 'Income': '67833', 'Card_Category': 'Blue'}
# {'Customer_Age': '30', 'Gender': 'M', 'Income': '65755', 'Card_Category': 'Blue'}
# {'Customer_Age': '36', 'Gender': 'F', 'Income': '37062', 'Card_Category': 'Blue'}
# {'Customer_Age': '53', 'Gender': 'F', 'Income': '191635', 'Card_Category': 'Silver'}
# {'Customer_Age': '38', 'Gender': 'M', 'Income': '108917', 'Card_Category': 'Blue'}
# {'Customer_Age': '38', 'Gender': 'M', 'Income': '115276', 'Card_Category': 'Silver'}
# {'Customer_Age': '43', 'Gender': 'M', 'Income': '100510', 'Card_Category': 'Blue'}
# {'Customer_Age': '35', 'Gender': 'M', 'Income': '117931', 'Card_Category': 'Blue'}
# {'Customer_Age': '40', 'Gender': 'F', 'Income': '2565', 'Card_Category': 'Blue'}
# {'Customer_Age': '56', 'Gender': 'F', 'Income': '19164', 'Card_Category': 'Blue'}
# {'Customer_Age': '62', 'Gender': 'M', 'Income': '50015', 'Card_Category': 'Blue'}
# {'Customer_Age': '59', 'Gender': 'M', 'Income': '46440', 'Card_Category': 'Blue'}
# {'Customer_Age': '47', 'Gender': 'F', 'Income': '35978', 'Card_Category': 'Blue'}
# {'Customer_Age': '57', 'Gender': 'F', 'Income': '29146', 'Card_Category': 'Blue'}
# {'Customer_Age': '46', 'Gender': 'F', 'Income': '34126', 'Card_Category': 'Silver'}
# {'Customer_Age': '41', 'Gender': 'F', 'Income': '41072', 'Card_Category': 'Blue'}
# {'Customer_Age': '31', 'Gender': 'F', 'Income': '19945', 'Card_Category': 'Blue'}
# {'Customer_Age': '55', 'Gender': 'M', 'Income': '118760', 'Card_Category': 'Blue'}
# {'Customer_Age': '39', 'Gender': 'M', 'Income': '73835', 'Card_Category': 'Blue'}
# {'Customer_Age': '53', 'Gender': 'F', 'Income': '199188', 'Card_Category': 'Gold'}
# {'Customer_Age': '41', 'Gender': 'F', 'Income': '57166', 'Card_Category': 'Blue'}
# {'Customer_Age': '53', 'Gender': 'M', 'Income': '154296', 'Card_Category': 'Blue'}
# {'Customer_Age': '52', 'Gender': 'F', 'Income': '9535', 'Card_Category': 'Blue'}
# {'Customer_Age': '57', 'Gender': 'F', 'Income': '28391', 'Card_Category': 'Blue'}
# {'Customer_Age': '50', 'Gender': 'M', 'Income': '105018', 'Card_Category': 'Blue'}
# {'Customer_Age': '51', 'Gender': 'F', 'Income': '14085', 'Card_Category': 'Blue'}
# {'Customer_Age': '53', 'Gender': 'M', 'Income': '180122', 'Card_Category': 'Silver'}
# {'Customer_Age': '56', 'Gender': 'M', 'Income': '108202', 'Card_Category': 'Silver'}
# {'Customer_Age': '47', 'Gender': 'M', 'Income': '65677', 'Card_Category': 'Blue'}
# {'Customer_Age': '48', 'Gender': 'M', 'Income': '85461', 'Card_Category': 'Blue'}
# {'Customer_Age': '52', 'Gender': 'F', 'Income': '183827', 'Card_Category': 'Blue'}
# {'Customer_Age': '55', 'Gender': 'M', 'Income': '145249', 'Card_Category': 'Silver'}
# {'Customer_Age': '53', 'Gender': 'F', 'Income': '217807', 'Card_Category': 'Blue'}
# {'Customer_Age': '34', 'Gender': 'M', 'Income': '52924', 'Card_Category': 'Blue'}
# {'Customer_Age': '61', 'Gender': 'F', 'Income': '36780', 'Card_Category': 'Blue'}
# {'Customer_Age': '53', 'Gender': 'F', 'Income': '113787', 'Card_Category': 'Blue'}
# {'Customer_Age': '36', 'Gender': 'M', 'Income': '65269', 'Card_Category': 'Blue'}
# {'Customer_Age': '33', 'Gender': 'F', 'Income': '28114', 'Card_Category': 'Blue'}
# {'Customer_Age': '28', 'Gender': 'M', 'Income': '41267', 'Card_Category': 'Blue'}
# {'Customer_Age': '46', 'Gender': 'F', 'Income': '36533', 'Card_Category': 'Silver'}
# {'Customer_Age': '55', 'Gender': 'F', 'Income': '24383', 'Card_Category': 'Blue'}
# {'Customer_Age': '47', 'Gender': 'M', 'Income': '117004', 'Card_Category': 'Blue'}
# {'Customer_Age': '43', 'Gender': 'M', 'Income': '88758', 'Card_Category': 'Blue'}
# {'Customer_Age': '65', 'Gender': 'F', 'Income': '38022', 'Card_Category': 'Silver'}
# {'Customer_Age': '42', 'Gender': 'M', 'Income': '78917', 'Card_Category': 'Blue'}
# {'Customer_Age': '43', 'Gender': 'M', 'Income': '47220', 'Card_Category': 'Blue'}
# {'Customer_Age': '39', 'Gender': 'F', 'Income': '20521', 'Card_Category': 'Blue'}
# {'Customer_Age': '44', 'Gender': 'M', 'Income': '109110', 'Card_Category': 'Blue'}
# {'Customer_Age': '42', 'Gender': 'M', 'Income': '115315', 'Card_Category': 'Silver'}
# {'Customer_Age': '52', 'Gender': 'M', 'Income': '93956', 'Card_Category': 'Blue'}
# {'Customer_Age': '58', 'Gender': 'M', 'Income': '102421', 'Card_Category': 'Blue'}
# {'Customer_Age': '37', 'Gender': 'M', 'Income': '76834', 'Card_Category': 'Blue'}
# {'Customer_Age': '52', 'Gender': 'M', 'Income': '74732', 'Card_Category': 'Blue'}
# {'Customer_Age': '37', 'Gender': 'M', 'Income': '69549', 'Card_Category': 'Blue'}
# {'Customer_Age': '56', 'Gender': 'M', 'Income': '113377', 'Card_Category': 'Silver'}
# {'Customer_Age': '46', 'Gender': 'M', 'Income': '101364', 'Card_Category': 'Silver'}
# {'Customer_Age': '32', 'Gender': 'M', 'Income': '170984', 'Card_Category': 'Blue'}
# {'Customer_Age': '38', 'Gender': 'F', 'Income': '57289', 'Card_Category': 'Blue'}
# {'Customer_Age': '61', 'Gender': 'M', 'Income': '14975', 'Card_Category': 'Blue'}
# {'Customer_Age': '42', 'Gender': 'M', 'Income': '59346', 'Card_Category': 'Blue'}
# {'Customer_Age': '65', 'Gender': 'F', 'Income': '44284', 'Card_Category': 'Blue'}
# {'Customer_Age': '55', 'Gender': 'F', 'Income': '23257', 'Card_Category': 'Blue'}
# {'Customer_Age': '40', 'Gender': 'M', 'Income':
 'Card_Category': 'Blue'}
# {'Customer_Age': '46', 'Gender': 'M', 'Income': '60698', 'Card_Category': 'Blue'}
# {'Customer_Age': '39', 'Gender': 'M', 'Income': '98039', 'Card_Category': 'Blue'}
# {'Customer_Age': '40', 'Gender': 'M', 'Income': '85529', 'Card_Category': 'Blue'}
# {'Customer_Age': '50', 'Gender': 'M', 'Income': '98147', 'Card_Category': 'Blue'}
# {'Customer_Age': '48', 'Gender': 'M', 'Income': '103619', 'Card_Category': 'Silver'}
# {'Customer_Age': '54', 'Gender': 'M', 'Income': '91315', 'Card_Category': 'Blue'}
# {'Customer_Age': '43', 'Gender': 'F', 'Income': '14975', 'Card_Category': 'Blue'}
# {'Customer_Age': '35', 'Gender': 'F', 'Income': '27545', 'Card_Category': 'Blue'}
# {'Customer_Age': '53', 'Gender': 'F', 'Income': '40118', 'Card_Category': 'Blue'}
# {'Customer_Age': '42', 'Gender': 'F', 'Income': '2565', 'Card_Category': 'Blue'}
# {'Customer_Age': '38', 'Gender': 'M', 'Income': '115009', 'Card_Category': 'Blue'}
# {'Customer_Age': '29', 'Gender': 'M', 'Income': '119424', 'Card_Category': 'Silver'}
# {'Customer_Age': '35', 'Gender': 'M', 'Income': '110765', 'Card_Category': 'Blue'}
# {'Customer_Age': '26', 'Gender': 'F', 'Income': '54388', 'Card_Category': 'Blue'}
# {'Customer_Age': '42', 'Gender': 'M', 'Income': '41595', 'Card_Category': 'Blue'}
# {'Customer_Age': '54', 'Gender': 'M', 'Income': '107587', 'Card_Category': 'Gold'}
# {'Customer_Age': '51', 'Gender': 'M', 'Income': '56521', 'Card_Category': 'Blue'}
# {'Customer_Age': '59', 'Gender': 'F', 'Income': '6550', 'Card_Category': 'Blue'}
# {'Customer_Age': '60', 'Gender': 'M', 'Income': '86471', 'Card_Category': 'Blue'}
# {'Customer_Age': '42', 'Gender': 'F', 'Income': '5225', 'Card_Category': 'Blue'}
# {'Customer_Age': '58', 'Gender': 'M', 'Income': '166510', 'Card_Category': 'Blue'}
# {'Customer_Age': '34', 'Gender': 'M', 'Income': '67814', 'Card_Category': 'Silver'}
# {'Customer_Age': '55', 'Gender': 'M', 'Income': '92487', 'Card_Category': 'Blue'}
# {'Customer_Age': '36', 'Gender': 'M', 'Income': '51579', 'Card_Category': 'Gold'}
# {'Customer_Age': '57', 'Gender': 'F', 'Income': '176223', 'Card_Category': 'Blue'}
# {'Customer_Age': '38', 'Gender': 'F', 'Income': '43640', 'Card_Category': 'Blue'}
# {'Customer_Age': '44', 'Gender': 'F', 'Income': '41569', 'Card_Category': 'Blue'}
# {'Customer_Age': '41', 'Gender': 'M', 'Income': '78182', 'Card_Category': 'Blue'}
# {'Customer_Age': '54', 'Gender': 'F', 'Income': '35066', 'Card_Category': 'Blue'}
# {'Customer_Age': '55', 'Gender': 'M', 'Income': '64004', 'Card_Category': 'Blue'}
# {'Customer_Age': '37', 'Gender': 'F', 'Income': '14975', 'Card_Category': 'Blue'}
# {'Customer_Age': '36', 'Gender': 'F', 'Income': '232465', 'Card_Category': 'Blue'}
# {'Customer_Age': '42', 'Gender': 'M', 'Income': '60132', 'Card_Category': 'Blue'}
# {'Customer_Age': '65', 'Gender': 'M', 'Income': '36634', 'Card_Category': 'Blue'}
# {'Customer_Age': '39', 'Gender': 'F', 'Income': '8250', 'Card_Category': 'Blue'}
# {'Customer_Age': '61', 'Gender': 'M', 'Income': '65807', 'Card_Category': 'Blue'}
# {'Customer_Age': '62', 'Gender': 'F', 'Income': '54132', 'Card_Category': 'Blue'}
# {'Customer_Age': '51', 'Gender': 'F', 'Income': '39079', 'Card_Category': 'Blue'}
# {'Customer_Age': '65', 'Gender': 'F', 'Income': '15266', 'Card_Category': 'Blue'}
# {'Customer_Age': '44', 'Gender': 'F', 'Income': '18058', 'Card_Category': 'Blue'}
# {'Customer_Age': '26', 'Gender': 'F', 'Income': '40913', 'Card_Category': 'Blue'}
# {'Customer_Age': '44', 'Gender': 'F', 'Income': '14975', 'Card_Category': 'Silver'}
# {'Customer_Age': '42', 'Gender': 'F', 'Income': '14975', 'Card_Category': 'Blue'}
# {'Customer_Age': '46', 'Gender': 'M', 'Income': '65289', 'Card_Category': 'Blue'}
# {'Customer_Age': '44', 'Gender': 'M', 'Income': '37157', 'Card_Category': 'Blue'}
# {'Customer_Age': '42', 'Gender': 'M', 'Income': '104155', 'Card_Category': 'Silver'}
# {'Customer_Age': '36', 'Gender': 'M', 'Income': '47755', 'Card_Category': 'Blue'}
# {'Customer_Age': '31', 'Gender': 'M', 'Income': '107590', 'Card_Category': 'Silver'}
# {'Customer_Age': '52', 'Gender': 'F', 'Income': '31242', 'Card_Category': 'Blue'}
# {'Customer_Age': '56', 'Gender': 'M', 'Income': '75263', 'Card_Category': 'Blue'}
# {'Customer_Age': '45', 'Gender': 'F', 'Income': '41363', 'Card_Category': 'Blue'}
# {'Customer_Age': '62', 'Gender': 'M', 'Income': '14975', 'Card_Category': 'Blue'}
# {'Customer_Age': '49', 'Gender': 'F', 'Income': '14272', 'Card_Category': 'Blue'}
# {'Customer_Age': '36', 'Gender': 'M', 'Income': '70005', 'Card_Category': 'Blue'}
# {'Customer_Age': '51', 'Gender': 'M', 'Income': '163579', 'Card_Category': 'Blue'}
# {'Customer_Age': '62', 'Gender': 'M', 'Income': '60939', 'Card_Category': 'Blue'}
# {'Customer_Age': '45', 'Gender': 'F', 'Income': '59935', 'Card_Category': 'Blue'}
# {'Customer_Age': '41', 'Gender': 'M', 'Income': '96094', 'Card_Category': 'Blue'}
# {'Customer_Age': '29', 'Gender': 'M', 'Income': '63126', 'Card_Category': 'Blue'}
# {'Customer_Age': '46', 'Gender': 'M', 'Income': '79693', 'Card_Category': 'Gold'}
# {'Customer_Age': '45', 'Gender': 'M', 'Income': '92221', 'Card_Category': 'Blue'}
# {'Customer_Age': '34', 'Gender': 'M', 'Income': '80291', 'Card_Category': 'Blue'}
# {'Customer_Age': '30', 'Gender': 'M', 'Income': '82252', 'Card_Category': 'Blue'}
# {'Customer_Age': '34', 'Gender': 'M', 'Income': '74150', 'Card_Category': 'Blue'}
# {'Customer_Age': '51', 'Gender': 'F', 'Income': '221101', 'Card_Category': 'Gold'}
# {'Customer_Age': '37', 'Gender': 'F', 'Income': '41205', 'Card_Category': 'Blue'}
# {'Customer_Age': '50', 'Gender': 'F', 'Income': '13514', 'Card_Category': 'Blue'}
# {'Customer_Age': '56', 'Gender': 'F', 'Income': '28036', 'Card_Category': 'Blue'}
# {'Customer_Age': '54', 'Gender': 'M', 'Income': '159788', 'Card_Category': 'Silver'}
# {'Customer_Age': '47', 'Gender': 'F', 'Income': '31462', 'Card_Category': 'Blue'}
# {'Customer_Age': '32', 'Gender': 'F', 'Income': '41047', 'Card_Category': 'Silver'}
# {'Customer_Age': '43', 'Gender': 'F', 'Income': '58406', 'Card_Category': 'Blue'}
# {'Customer_Age': '48', 'Gender': 'F', 'Income': '32356', 'Card_Category': 'Blue'}
# {'Customer_Age': '35', 'Gender': 'F', 'Income': '31217', 'Card_Category': 'Silver'}
# {'Customer_Age': '43', 'Gender': 'M', 'Income': '42413', 'Card_Category': 'Blue'}
# {'Customer_Age': '48', 'Gender': 'M', 'Income': '48514', 'Card_Category': 'Blue'}
# {'Customer_Age': '61', 'Gender': 'F', 'Income': '19589', 'Card_Category': 'Blue'}
# {'Customer_Age': '32', 'Gender': 'F', 'Income': '27581', 'Card_Category': 'Blue'}
# {'Customer_Age': '37', 'Gender': 'F', 'Income': '24386', 'Card_Category': 'Blue'}
# {'Customer_Age': '49', 'Gender': 'M', 'Income': '157422', 'Card_Category': 'Silver'}
# {'Customer_Age': '34', 'Gender': 'M', 'Income': '110689', 'Card_Category': 'Blue'}
# {'Customer_Age': '28', 'Gender': 'M', 'Income': '59790', 'Card_Category': 'Blue'}
# {'Customer_Age': '55', 'Gender': 'M', 'Income': '83442', 'Card_Category': 'Blue'}
# {'Customer_Age': '61', 'Gender': 'M', 'Income': '98139', 'Card_Category': 'Blue'}
# {'Customer_Age': '30', 'Gender': 'F', 'Income': '14505', 'Card_Category': 'Blue'}
# {'Customer_Age': '41', 'Gender': 'M', 'Income': '183148', 'Card_Category': 'Blue'}
# {'Customer_Age': '45', 'Gender': 'F', 'Income': '25100', 'Card_Category': 'Blue'}
# {'Customer_Age': '53', 'Gender': 'F', 'Income': '25397', 'Card_Category': 'Blue'}
# {'Customer_Age': '46', 'Gender': 'M', 'Income': '59578', 'Card_Category': 'Blue'}
# {'Customer_Age': '51', 'Gender': 'M', 'Income': '153063', 'Card_Category': 'Gold'}
# {'Customer_Age': '59', 'Gender': 'M', 'Income': '62723', 'Card_Category': 'Blue'}
# {'Customer_Age': '62', 'Gender': 'M', 'Income': '79913', 'Card_Category': 'Blue'}
# {'Customer_Age': '34', 'Gender': 'F', 'Income': '54933', 'Card_Category': 'Blue'}
# {'Customer_Age': '54', 'Gender': 'M', 'Income': '105311', 'Card_Category': 'Blue'}
# {'Customer_Age': '43', 'Gender': 'M', 'Income': '72387', 'Card_Category': 'Blue'}
# {'Customer_Age': '60', 'Gender': 'M', 'Income': '65907', 'Card_Category': 'Blue'}
# {'Customer_Age': '54', 'Gender': 'M', 'Income': '104292', 'Card_Category': 'Blue'}
# {'Customer_Age': '56', 'Gender': 'F', 'Income': '56959', 'Card_Category': 'Blue'}
# {'Customer_Age': '46', 'Gender': 'M', 'Income': '66306', 'Card_Category': 'Blue'}
# {'Customer_Age': '41', 'Gender': 'M', 'Income': '76632', 'Card_Category': 'Blue'}
# {'Customer_Age': '33', 'Gender': 'M', 'Income': '104552', 'Card_Category': 'Blue'}
# {'Customer_Age': '39', 'Gender': 'F', 'Income': '38548', 'Card_Category': 'Blue'}

# %%
def retrieve_by_marital_status_and_dependents(file_name, marital_status, min_dependents):
    results = []

    try:
        with open(file_name, 'r', encoding='UTF-8') as csv_file:
            csv_reader = csv.DictReader(csv_file)

            for row in csv_reader:
                if row['marital_status'] == marital_status and int(row['dependents']) > min_dependents:
                    results.append({
                        'age': row['age'],
                        'gender': row['gender'],
                        'education_level': row['education_level'],
                        'job': row['job']
                    })

        return results

    except FileNotFoundError:
        print(f"File {file_name} not found.")
        return []

# Example Usage:
marital_status = 'Married'
min_dependents = 3
data = retrieve_by_marital_status_and_dependents(file_name, marital_status, min_dependents)
print(data)

# %%
def retrieve_by_condition(file_name, column1, column2, column3, condition):
    results = []

    try:
        with open(file_name, 'r', encoding='UTF-8') as csv_file:
            csv_reader = csv.DictReader(csv_file)

            for row in csv_reader:
                # Apply the condition. Example condition: income > 50000
                if float(row[column1]) > condition:
                    results.append({
                        column1: row[column1],
                        column2: row[column2],
                        column3: row[column3]
                    })

        return results

    except FileNotFoundError:
        print(f"File {file_name} not found.")
        return []

# Example Usage:
column1 = 'income'
column2 = 'gender'
column3 = 'education_level'
condition = 50000  # Condition: Income greater than 50,000
data = retrieve_by_condition(file_name, column1, column2, column3, condition)
print(data)
