# %%
import csv

csv_list = []  # Empty list to store data

while True:
    file_name = input("Enter your file name or press enter to quit: ")

    if not file_name:  # If input is empty, exit the program
        print("Exiting the program.")
        break  # Exit loop

    try:
        # Open the CSV file
        with open(file_name, 'r', encoding='UTF-8') as csv_file:
            csv_reader = csv.reader(csv_file)
            
            
            # Read and store data using a for loop
            for row in csv_reader:
                data_list.append(row)  # Append each row to the list
            
        break  # Exit loop after successfully reading the file

    except FileNotFoundError as e:
        print(f"File does not exist: {e}")  # Allow user to try again
# Out:
# Enter your file name or press enter to quit:  credit_card_customers.csv
# credit_card_customers.csv is opening
# ...

# %%
#Retrieve the client number, gender, education level, and income of customers based on their card category

card_catergory = input("Enter your card catergory :")
print (card_catergory)

for row in range
# Out:
# Enter your card catergory : BLue
# BLue
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 7
#       4 print (card_catergory)
#       6 for row in card_catergory:
# ----> 7     if cat == card_catergory.split(','):
#       8         print(f"Clients number : {row[0]}, Gender : {row[2]}, Education level : {row[4]}, Income : {row[13]}")
#
# NameError: name 'cat' is not defined
