# %%
def load_csv_file():
    csv_list = []
    while True:
        file_name = input("Enter the CSV file name or enter 'q' to quit the program: ")
        if file_name.lower() == 'q':
            print("Exiting the program.")
            return None
        try:
            with open(file_name, 'r', encoding='UTF-8') as csv_file:
                csv_list.clear()
                for line in csv_file:
                    csv_list.append(line.strip().split(','))
            print("CSV file loaded successfully.")
            return csv_list
        except FileNotFoundError as e:
            print(f"File does not exist: {e}")

def filter_by_card_category(csv_list):
    print("\nRetrieve client number, gender, education level, and income based on card category.")
    card_options = {'1': 'BLUE', '2': 'PLATINUM', '3': 'GOLD', '4': 'SILVER'}
    
    while True:
        print("\nSelect a Card Category:")
        for key, value in card_options.items():
            print(f"{key}. {value.capitalize()}")
        print("q. Quit Program")

        user_input = input("Enter your choice (1-4) or 'q': ").strip()

        if user_input.lower() == 'q':
            return 'quit'
        if user_input not in card_options:
            print("Invalid option. Try again.")
            continue

        selected_category = card_options[user_input]
        card_category = []

        for row in csv_list[1:]:
            if row[15].upper() == selected_category:
                card_category.append([row[0], row[2], row[4], row[13]])

        if card_category:
            print(f"\n{'Client_Num':<12} {'Gender':<8} {'Education_Level':<15} {'Income':<10}")
            print("_" * 45)
            for item in card_category:
                print(f"{item[0]:<12} {item[1]:<8} {item[2]:<15} {item[3]:<10}")
        else:
            print(f"No data found for the category '{selected_category}'.")

        break

def filter_by_state(csv_list):
    print("\nRetrieve the age, gender, income, and credit card category of customers based on state of residence.")

    while True:
        print("\nType the State abbreviation (e.g., NY, TX, CA) or 'q' to quit the program.")
        user_input = input("Enter state abbreviation: ").strip().upper()

        if user_input.lower() == 'q':
            return 'quit'
        
        matching_data = []

        for row in csv_list[1:]:
            if row[6].upper() == user_input:
                matching_data.append([row[1], row[2], row[13], row[15]])

        if matching_data:
            print(f"\n{'Customer_Age':<15} {'Gender':<8} {'Income':<10} {'Card_Category':<15}")
            print("-" * 50)
            for item in matching_data:
                print(f"{item[0]:<15} {item[1]:<8} {item[2]:<10} {item[3]:<15}")
        else:
            print(f"No data found for state '{user_input}'.")

        break

def filter_by_marital_and_dependents(csv_list):
    print("\nRetrieve age, gender, education level, and job of customers based on marital status and dependents.")

    while True:
        marital_options = {'1': 'Single', '2': 'Married', '3': 'Unknown'}
        print("\nSelect Marital Status:")
        for key, value in marital_options.items():
            print(f"{key}. {value}")
        print("q. Quit Program")

        user_input = input("Enter your choice (1-3) or 'q': ").strip()

        if user_input.lower() == 'q':
            return 'quit'
        if user_input not in marital_options:
            print("Invalid option. Try again.")
            continue

        selected_marital = marital_options[user_input]
        marital_status = []

        for row in csv_list[1:]:
            if row[5].lower() == selected_marital.lower() and int(row[3]) > 3:
                marital_status.append([row[1], row[2], row[4], row[12]])

        if marital_status:
            print(f"\n{'Age':<15} {'Gender':<10} {'Education Level':<15} {'Customer Job':<10}")
            print("_" * 55)
            for item in marital_status:
                print(f"{item[0]:<15} {item[1]:<10} {item[2]:<15} {item[3]:<10}")
        else:
            print(f"No data found for marital status '{selected_marital}' with more than 3 dependents.")

        break

def filter_by_loan_and_age(csv_list):
    print("\nRetrieve the job, income, car ownership, and gender of customers older than 25 based on loan status.")

    while True:
        loan_options = {'1': 'yes', '2': 'no'}
        print("\nSelect Loan Status:")
        for key, value in loan_options.items():
            print(f"{key}. {value.capitalize()}")
        print("q. Quit Program")

        user_input = input("Enter your choice (1-2) or 'q': ").strip()

        if user_input.lower() == 'q':
            return 'quit'
        if user_input not in loan_options:
            print("Invalid option. Try again.")
            continue

        selected_loan = loan_options[user_input]
        loan_and_gender = []

        for row in csv_list[1:]:
            if row[10].lower() == selected_loan and int(row[1]) > 25:
                loan_and_gender.append([row[12], row[13], row[8], row[2]])

        if loan_and_gender:
            print(f"\n{'Customer_Job':<15} {'Income':<10} {'Car_Owner':<8} {'Gender':<10}")
            print("-" * 45)
            for item in loan_and_gender:
                print(f"{item[0]:<15} {item[1]:<10} {item[2]:<8} {item[3]:<10}")
        else:
            print(f"No data found for loan status '{selected_loan}' and age > 25.")

        break

def main():
    csv_list = load_csv_file()
    if csv_list is None:
        return

    filters = {
        '1': ('Filter by Card Category (Task a1)', filter_by_card_category),
        '2': ('Filter by State  (Task a2)', filter_by_state),
        '3': ('Filter by Marital Status and Dependents  (Task a3)', filter_by_marital_and_dependents),
        '4': ('Filter by Loan Status and Age > 25  (Task a4)', filter_by_loan_and_age),
        '0': ('Quit Program', None)
    }

    while True:
        print("\n=== Main Menu ===")
        for key, (desc, _) in filters.items():
            print(f"{key}. {desc}")

        choice = input("Enter your choice (1-4) or '0' to quit: ").strip()

        if choice == '0':
            print("\nThank you for using our customer data explorer. Goodbye!")
            break
        elif choice in filters:
            _, selected_filter_function = filters[choice]
            if selected_filter_function is None:
                break

            while True:
                status = selected_filter_function(csv_list)
                if status == 'quit':
                    print("\nThank you for using our customer data explorer. Goodbye!")
                    return

                print("\nDo you want to:")
                print("1. Try the same filter again")
                print("2. Go back to main menu")
                print("0. Quit Program")

                sub_choice = input("Enter 1, 2, or 0: ").strip()

                if sub_choice == '1':
                    continue
                elif sub_choice == '2':
                    break
                elif sub_choice == '0':
                    print("\nThank you for using our customer data explorer. Goodbye!")
                    return
                else:
                    print("Invalid input. Returning to main menu.")
                    break
        else:
            print("Invalid option. Please select from the menu.")

# Run the main program
main()
# Out:
# Enter the CSV file name or enter 'q' to quit the program:  credit_card_customers.csv
# CSV file loaded successfully.
#
# === Main Menu ===
# 1. Filter by Card Category (Task a1)
# 2. Filter by State  (Task a2)
# 3. Filter by Marital Status and Dependents  (Task a3)
# 4. Filter by Loan Status and Age > 25  (Task a4)
# 0. Quit Program
# Enter your choice (1-4) or '0' to quit:  2
# Retrieve the age, gender, income, and credit card category of customers based on state of residence.
#
# Type the State abbreviation (e.g., NY, TX, CA) or 'q' to quit the program.
# Enter state abbreviation:  tx
# Customer_Age    Gender   Income     Card_Category
# --------------------------------------------------
# 48              M        59279      Blue
# 49              F        20632      Blue
# 34              F        53762      Blue
# 63              M        14975      Blue
# 49              F        44555      Blue
# 43              F        12381      Blue
# 47              F        27517      Silver
# 44              F        44883      Blue
# 40              F        16041      Blue
# 62              M        67827      Blue
# 44              F        35755      Blue
# 60              F        24156      Blue
# 48              F        57686      Blue
# 37              F        25423      Blue
# 54              F        14975      Blue
# 44              M        131861     Blue
# 49              F        14975      Blue
# 56              M        116230     Blue
# 45              F        24058      Blue
# 51              F        1250       Blue
# 49              F        166923     Blue
# 48              M        64665      Blue
# 56              F        14975      Silver
# 40              M        82412      Blue
# 42              M        60037      Blue
# 50              M        86281      Blue
# 41              F        20495      Blue
# 43              F        21828      Blue
# 35              F        30259      Blue
# 37              M        165306     Blue
# 55              F        45818      Blue
# 41              F        12775      Blue
# 44              M        76246      Blue
# 41              M        30828      Blue
# 33              F        6550       Blue
# 50              M        108894     Blue
# 51              M        219668     Silver
# 45              F        23898      Blue
# 56              F        38817      Blue
# 34              F        1250       Blue
# 45              F        53906      Blue
# 42              F        52148      Blue
# 43              M        62768      Blue
# 50              F        36188      Blue
# 51              F        13704      Gold
# 41              F        12686      Blue
# 44              F        26226      Blue
# 35              F        16316      Blue
# 42              M        65425      Blue
# 60              F        30594      Blue
# 42              F        12264      Blue
# 57              F        27897      Blue
# 42              M        115771     Blue
# 48              F        14975      Blue
# 46              M        116731     Blue
# 40              F        23108      Blue
# 52              F        32691      Blue
# 32              F        29521      Blue
# 44              F        34283      Blue
# 44              F        15508      Blue
# 46              M        117419     Blue
# 45              F        40495      Blue
# 49              M        209698     Gold
# 41              M        43782      Blue
# 45              F        30135      Blue
# 49              F        33335      Blue
# 54              F        19789      Blue
# 32              F        34492      Blue
# 50              M        81981      Blue
# 44              F        20382      Blue
# 60              F        15554      Blue
# 47              F        1250       Blue
# 35              M        94935      Blue
# 47              F        13428      Blue
# 53              M        173245     Blue
# 41              M        55954      Blue
# 49              F        41046      Silver
# 51              F        14975      Blue
# 39              F        54491      Blue
# 60              F        36679      Blue
# 48              F        37495      Blue
# 40              F        28751      Blue
# 48              M        63958      Blue
# 46              M        114524     Silver
# 46              M        83512      Blue
# 59              F        2565       Blue
# 42              F        25056      Blue
# 52              F        23048      Blue
# 38              F        5225       Blue
# 41              M        60076      Blue
# 37              M        82470      Blue
# 48              M        51569      Blue
# 43              M        113270     Blue
# 39              F        6550       Blue
# 56              F        16430      Blue
# 45              F        23530      Blue
# 47              F        47088      Blue
# 53              M        85957      Blue
# 46              F        53739      Blue
# 49              M        236628     Platinum
# 40              F        17285      Blue
# 52              M        76611      Blue
# 57              F        30585      Blue
# 41              F        6550       Blue
# 59              M        10194      Blue
# 35              F        14975      Blue
# 50              M        96537      Blue
# 44              F        50852      Blue
# 48              F        1250       Blue
# 52              M        69680      Blue
# 48              F        16051      Blue
# 34              F        14975      Blue
# 40              F        14975      Blue
# 48              M        99344      Blue
# 47              M        56113      Blue
# 49              F        12398      Blue
# 47              F        24338      Blue
# 49              F        14885      Blue
# 43              M        68405      Blue
# 45              M        67969      Blue
# 39              M        116281     Blue
# 49              M        118266     Blue
# 57              F        14975      Blue
# 48              M        10072      Silver
# 38              M        132948     Blue
# 48              F        14975      Blue
# 30              M        10008      Blue
# 65              F        35984      Silver
# 61              F        20360      Blue
# 59              F        36712      Blue
# 40              F        42026      Blue
# 52              F        2565       Blue
# 43              M        57805      Blue
# 55              F        14975      Blue
# 56              F        5525       Blue
# 49              F        226745     Gold
# 52              M        92226      Blue
# 60              F        25163      Blue
# 47              F        20658      Blue
# 50              M        81810      Blue
# 49              F        13302      Blue
# 39              M        98780      Blue
# 42              M        204097     Blue
# 59              M        15643      Blue
# 44              F        34598      Blue
# 54              F        18923      Blue
# 53              M        127012     Blue
# 47              F        20395      Blue
# 51              F        21594      Blue
# 52              M        66923      Blue
# 35              F        26315      Blue
# 42              F        16153      Blue
# 52              F        167572     Blue
# 57              M        170387     Blue
# 44              M        62843      Blue
# 53              M        112375     Blue
# 60              M        72542      Blue
# 44              F        43432      Silver
# 56              F        11202      Blue
# 58              M        107744     Blue
# 63              M        49497      Blue
# 54              M        10019      Blue
# 42              F        28104      Blue
# 30              F        15446      Blue
# 44              F        14975      Blue
# 35              M        80777      Blue
# 59              M        114711     Blue
# 38              M        95473      Blue
# 44              M        68783      Blue
# 47              F        18482      Blue
# 55              F        36899      Blue
# 37              M        48436      Blue
# 35              F        49630      Blue
# 42              M        98960      Blue
# 52              M        92593      Blue
# 47              F        14975      Blue
# 50              F        46567      Blue
# 45              M        42191      Blue
# 41              M        104384     Blue
# 43              F        48357      Silver
# 62              F        27552      Blue
# 29              M        51868      Blue
# 58              M        60839      Blue
# 36              F        16094      Blue
# 47              M        110342     Blue
# 41              M        85981      Blue
# 39              M        126439     Silver
# 55              M        60020      Gold
# 58              F        14975      Blue
# 51              M        114988     Blue
# 34              F        15484      Blue
# 42              M        45716      Blue
# 49              M        46013      Blue
# 41              M        54328      Blue
# 45              F        5225       Blue
# 43              M        58964      Blue
# 52              M        109516     Silver
# 42              F        12512      Silver
# 55              F        220595     Blue
# 49              F        21188      Blue
# 53              F        13600      Blue
# 47              M        56565      Blue
# 52              F        50129      Blue
# 47              F        11150      Blue
# 44              F        52717      Blue
# 46              F        11588      Blue
# 49              F        12445      Blue
# 54              F        32073      Blue
# 51              F        52811      Blue
# 37              F        51900      Blue
# 47              F        16670      Blue
# 53              F        128211     Blue
# 51              F        9535       Silver
# 37              F        22329      Blue
# 41              F        43253      Blue
# 45              M        101185     Blue
# 57              M        89211      Blue
# 39              M        118482     Gold
# 55              F        39474      Blue
# 53              M        116314     Blue
# 50              F        25503      Blue
# 52              M        53374      Blue
# 43              F        12846      Blue
# 42              F        14397      Blue
# 50              M        147696     Silver
# 45              F        35216      Blue
# 56              F        27492      Blue
# 49              F        30862      Blue
# 47              M        110796     Blue
# 39              M        38051      Blue
# 43              F        207019     Blue
# 41              F        28141      Blue
# 50              F        14435      Blue
# 42              M        66374      Blue
# 60              F        55125      Blue
# 52              M        56763      Blue
# 48              F        51233      Blue
# 45              F        56519      Blue
# 52              F        14975      Blue
# 49              M        122023     Blue
# 40              F        5525       Blue
# 39              F        13158      Blue
# 55              F        14975      Blue
# 43              M        78229      Blue
# 47              F        18342      Blue
# 33              F        12150      Blue
# 55              M        42002      Blue
# 61              M        66385      Blue
# 43              F        49637      Blue
# 45              F        58067      Blue
# 58              F        15525      Blue
# 49              M        43986      Blue
# 38              F        22834      Blue
# 36              F        19577      Blue
# 39              F        34733      Blue
# 49              M        24146      Blue
# 57              F        21397      Blue
# 56              F        22499      Blue
# 42              F        201560     Blue
# 48              F        22323      Blue
# 22              M        158267     Blue
# 50              F        27773      Blue
# 51              M        90785      Blue
# 62              M        69810      Blue
# 45              M        25019      Blue
# 50              F        28851      Blue
# 63              M        58252      Blue
# 48              F        29683      Silver
# 40              F        14975      Blue
# 53              F        51060      Blue
# 43              F        44964      Blue
# 59              F        41331      Blue
# 42              F        43563      Blue
# 42              M        67735      Blue
# 40              F        37037      Blue
# 45              F        22042      Blue
# 39              F        46200      Blue
# 43              F        49950      Blue
# 35              F        14975      Blue
# 58              M        94619      Blue
# 47              M        49214      Blue
# 41              F        28385      Blue
# 40              F        22508      Blue
# 54              F        32719      Blue
# 46              F        14975      Silver
# 43              F        214047     Blue
# 53              F        44538      Blue
# 43              F        33866      Silver
# 37              M        44847      Blue
# 55              F        49453      Blue
# 49              M        63745      Blue
# 43              F        35973      Blue
# 50              F        21465      Blue
# 32              F        2565       Blue
# 43              F        44670      Blue
# 47              M        85244      Blue
# 49              F        148823     Gold
# 45              M        70790      Blue
# 49              F        14975      Blue
# 59              F        6550       Silver
# 40              M        66761      Blue
# 43              M        55039      Blue
# 34              M        36479      Blue
# 44              M        51919      Blue
# 37              F        16851      Blue
# 50              F        44796      Blue
# 45              M        92180      Blue
# 48              M        77077      Silver
# 45              M        102550     Blue
# 35              F        14975      Blue
# 46              F        40886      Blue
# 50              F        196680     Blue
# 38              M        60709      Blue
# 47              F        12180      Blue
# 31              M        97871      Blue
# 47              F        13530      Blue
# 54              F        54316      Blue
# 51              M        82175      Blue
# 50              M        79812      Blue
# 48              M        39112      Blue
# 44              F        32978      Blue
# 32              F        44556      Blue
# 43              F        41075      Blue
# 53              F        12202      Blue
# 40              M        62397      Blue
# 51              F        14785      Blue
# 42              F        33381      Silver
# 39              F        38584      Silver
# 57              F        52360      Blue
# 39              M        83299      Blue
# 23              M        145541     Blue
# 46              F        37346      Blue
# 50              M        112083     Blue
# 49              F        27927      Blue
# 31              F        11925      Blue
# 45              M        116604     Blue
# 36              F        33043      Blue
# 36              F        5225       Blue
# 47              F        173452     Blue
# 44              F        45711      Silver
# 51              M        78985      Blue
# 51              M        115554     Blue
# 41              F        43433      Blue
# 45              F        17895      Blue
# 38              F        1250       Blue
# 34              F        18413      Blue
# 53              M        93119      Blue
# 34              F        43308      Blue
# 32              F        24806      Blue
# 49              F        36309      Blue
# 43              F        13600      Blue
# 51              F        31052      Blue
# 46              F        14975      Silver
# 42              F        36149      Silver
# 43              F        22764      Blue
# 39              F        18595      Blue
# 52              F        49717      Blue
# 45              F        2565       Blue
# 41              M        117221     Platinum
# 53              M        115217     Blue
# 46              F        58265      Blue
# 45              F        27992      Blue
# 53              F        14975      Blue
# 59              M        59786      Blue
# 45              M        52700      Blue
# 38              M        119886     Blue
# 62              F        40470      Blue
# 38              F        17853      Blue
# 51              M        97463      Blue
# 45              M        85978      Blue
# 50              M        92809      Blue
# 52              F        34273      Silver
# 43              F        38679      Blue
# 48              F        18647      Blue
# 56              F        5525       Blue
# 36              F        18984      Blue
# 42              F        35236      Blue
# 50              F        22093      Blue
# 49              M        103833     Gold
# 47              M        113241     Blue
# 40              M        10084      Blue
# 55              M        152039     Blue
# 47              M        62398      Blue
# 53              F        17961      Blue
# 52              M        110988     Blue
# 48              F        50789      Blue
# 51              M        65856      Blue
# 36              M        165526     Silver
# 49              F        32454      Blue
# 42              F        15960      Blue
# 39              M        102628     Blue
# 44              F        224581     Gold
# 37              F        35444      Blue
# 35              F        22915      Blue
# 40              F        17427      Blue
# 53              F        14975      Blue
# 48              F        7865       Blue
# 47              M        75462      Blue
# 44              F        14975      Blue
# 51              F        59744      Blue
# 51              M        84053      Silver
# 45              M        52603      Blue
# 44              F        46410      Blue
# 39              F        51611      Blue
# 31              M        96744      Blue
# 53              F        18991      Blue
# 40              M        107674     Silver
# 48              F        48973      Blue
# 56              F        38851      Blue
# 50              M        64532      Blue
# 46              M        42339      Blue
# 42              M        68048      Blue
# 43              F        21439      Blue
# 46              F        14975      Blue
# 55              F        45867      Blue
# 45              F        23841      Blue
# 36              F        212644     Silver
# 56              F        24671      Blue
# 52              F        35656      Blue
# 52              M        106074     Blue
# 40              M        72414      Blue
# 45              F        33075      Blue
# 47              M        79994      Blue
# 41              F        15777      Blue
# 45              F        56032      Blue
# 59              F        28605      Blue
# 50              M        99890      Blue
# 43              M        49563      Blue
# 55              F        14975      Blue
# 53              M        76696      Blue
# 57              F        27286      Blue
# 54              F        2565       Blue
# 43              F        17271      Blue
# 48              F        31646      Blue
# 41              M        93515      Blue
# 52              F        48695      Blue
# 48              M        70588      Blue
# 52              F        20977      Blue
# 41              M        61657      Blue
# 55              M        74464      Blue
# 44              F        8250       Blue
# 58              M        78857      Blue
# 48              F        47176      Silver
# 49              F        14975      Blue
# 49              F        12773      Silver
# 40              F        39913      Blue
# 62              F        36473      Blue
# 47              M        118797     Blue
# 47              M        68534      Blue
# 45              F        51059      Blue
# 45              F        152497     Blue
# 47              M        107419     Blue
# 50              M        32063      Blue
# 47              F        12914      Blue
# 43              M        79911      Blue
# 53              F        37954      Blue
# 40              F        43228      Blue
# 45              M        78352      Blue
# 57              M        95669      Blue
# 48              F        1250       Blue
# 56              F        107568     Blue
# 25              M        68957      Blue
# 47              F        20390      Blue
# 42              M        119658     Gold
# 40              F        24108      Blue
# 41              F        15309      Blue
# 43              M        55400      Blue
# 49              F        34722      Blue
# 42              F        35287      Blue
# 39              F        228681     Blue
# 43              M        77405      Blue
# 53              F        25200      Blue
# 42              M        77429      Blue
# 48              M        64838      Gold
# 49              F        2565       Blue
# 41              M        45049      Blue
# 49              F        33256      Blue
# 49              F        136787     Blue
# 62              F        28257      Blue
# 52              F        116723     Silver
# 50              M        10046      Blue
# 39              M        79681      Blue
# 43              F        13782      Blue
# 39              F        33110      Blue
# 51              F        26236      Blue
# 40              F        12518      Blue
# 41              M        45491      Blue
# 50              M        135983     Blue
# 42              F        15828      Blue
# 47              M        48548      Blue
# 32              F        17226      Blue
# 37              M        150611     Blue
# 43              M        112762     Blue
# 44              M        95433      Blue
# 44              M        63157      Blue
# 46              F        55645      Blue
# 40              F        31452      Blue
# 53              F        8250       Blue
# 46              F        25668      Blue
# 50              F        26749      Blue
# 43              F        23812      Blue
# 44              F        206224     Blue
# 55              F        32450      Blue
# 44              F        30527      Blue
# 44              M        66807      Blue
# 44              F        34127      Blue
# 49              F        34589      Blue
# 40              F        186470     Blue
# 28              F        6550       Blue
# 52              M        49232      Blue
# 46              M        41441      Blue
# 48              F        2565       Blue
# 39              F        49456      Blue
# 50              F        24646      Blue
# 50              M        77314      Blue
# 53              M        85919      Blue
# 39              M        108791     Blue
# 50              F        43193      Blue
# 37              F        22567      Blue
# 40              F        14975      Blue
# 47              F        14975      Silver
# 43              F        21084      Blue
# 42              F        24583      Blue
# 49              F        34310      Blue
# 50              M        113320     Blue
# 50              M        83466      Blue
# 43              F        11069      Blue
# 50              M        52200      Blue
# 31              F        26871      Blue
# 38              F        17432      Blue
# 50              F        19442      Blue
# 44              F        45295      Blue
# 38              F        31149      Blue
# 45              F        26430      Blue
# 58              M        109314     Blue
# 45              F        18319      Blue
# 58              F        14975      Blue
# 54              F        14975      Blue
# 45              M        93711      Blue
# 47              F        31610      Blue
# 56              F        28230      Blue
# 38              F        38304      Blue
# 43              F        13774      Blue
# 45              F        31945      Blue
# 54              M        79642      Blue
# 39              F        102012     Silver
# 42              M        180767     Gold
# 44              F        23184      Blue
# 43              F        32938      Blue
# 46              M        86659      Blue
# 57              M        144014     Blue
# 38              F        14975      Blue
# 45              F        40705      Blue
# 49              F        15188      Blue
# 54              F        12139      Blue
# 43              F        14745      Blue
# 55              F        17936      Blue
# 55              F        8250       Blue
# 50              M        156583     Blue
# 53              M        75419      Blue
# 44              F        24994      Blue
# 29              M        37941      Silver
# 42              F        33986      Blue
# 48              F        14975      Blue
# 49              M        103446     Gold
# 46              F        21799      Blue
# 53              M        67440      Blue
# 35              M        57140      Blue
# 40              M        57543      Blue
# 39              M        88551      Blue
# 45              F        17241      Blue
# 44              F        41559      Blue
# 52              F        12327      Silver
# 48              M        54826      Blue
# 44              M        76221      Blue
# 50              F        19255      Blue
# 48              F        38813      Blue
# 63              F        17298      Blue
# 48              F        2565       Blue
# 59              F        48316      Blue
# 47              F        51090      Blue
# 31              F        22025      Blue
# 53              F        41404      Blue
# 51              M        89811      Blue
# 49              F        53618      Blue
# 47              F        29460      Blue
# 55              M        121440     Silver
# 40              F        16415      Blue
# 44              F        39984      Blue
# 36              M        109016     Blue
# 60              F        9535       Blue
# 40              M        98857      Blue
# 51              F        41571      Silver
# 46              M        69005      Blue
# 49              M        93146      Blue
# 49              F        10919      Blue
# 38              M        60733      Blue
# 62              M        58730      Blue
# 55              M        94744      Blue
# 43              F        44365      Blue
# 28              M        41394      Blue
# 46              M        81937      Blue
# 41              F        42627      Blue
# 43              F        32524      Blue
# 45              F        44119      Blue
# 46              F        19987      Blue
# 45              F        11478      Blue
# 44              M        41393      Blue
# 48              M        72248      Blue
# 46              M        64831      Silver
# 61              M        78602      Blue
# 48              F        34635      Blue
# 45              M        117030     Blue
# 55              M        63218      Silver
# 54              F        16413      Blue
# 47              M        55954      Blue
# 44              M        44735      Blue
# 43              M        78891      Blue
# 51              M        113808     Blue
# 39              M        95430      Blue
# 47              M        15826      Blue
# 46              M        64234      Blue
# 48              F        18074      Blue
# 41              M        64397      Blue
# 47              F        36564      Blue
# 57              F        226140     Blue
# 59              M        56999      Blue
# 56              F        31603      Blue
# 52              M        82758      Blue
# 46              M        115685     Blue
# 57              M        84362      Blue
# 32              M        65287      Blue
# 44              M        67668      Blue
# 61              M        75172      Blue
# 45              M        76265      Blue
# 32              F        10584      Blue
# 40              M        96095      Blue
# 39              F        32532      Blue
# 41              M        99709      Blue
# 59              F        37238      Blue
# 48              F        49078      Blue
# 47              F        25295      Blue
# 38              F        1250       Blue
# 60              F        35474      Blue
# 35              F        14975      Blue
# 47              M        69069      Blue
# 54              F        220739     Blue
# 45              F        31319      Blue
# 44              M        43853      Blue
# 51              F        21320      Blue
# 58              F        34894      Blue
# 46              F        59945      Blue
# 41              F        36930      Blue
# 42              F        20313      Blue
# 52              F        16254      Blue
# 44              F        5525       Blue
# 61              M        55739      Blue
# 46              F        36521      Blue
# 60              F        35582      Blue
# 47              M        72423      Blue
# 54              M        119617     Silver
# 49              M        61838      Blue
# 52              M        52904      Blue
# 43              F        14975      Blue
# 62              M        77658      Blue
# 46              F        10861      Blue
# 47              M        64507      Blue
# 43              F        20154      Blue
# 28              M        14975      Blue
# 48              F        29519      Blue
# 35              F        32375      Blue
# 41              M        98081      Blue
# 47              M        80014      Blue
# 46              M        85402      Blue
# 52              M        69108      Blue
# 48              M        72413      Blue
# 43              M        141776     Silver
# 34              M        40083      Blue
# 48              F        34152      Blue
# 50              F        24066      Blue
# 64              M        18800      Blue
# 59              F        14975      Blue
# 31              F        30341      Silver
# 40              F        57928      Blue
# 36              F        2565       Blue
# 49              M        114091     Platinum
# 54              M        102583     Blue
# 57              F        17879      Blue
# 53              F        176762     Blue
# 54              F        35818      Blue
# 45              M        64868      Blue
# 39              F        20925      Blue
# 43              M        50765      Blue
# 45              F        46348      Silver
# 49              F        9535       Blue
# 49              F        21987      Blue
# 48              F        17924      Blue
# 55              F        14421      Blue
# 48              F        34925      Blue
# 49              F        34791      Blue
# 56              F        55977      Blue
# 43              F        17801      Blue
# 52              F        10467      Blue
# 48              F        48080      Blue
# 40              F        24974      Blue
# 49              F        33228      Blue
# 34              M        100760     Silver
# 39              F        35786      Silver
# 42              F        33779      Blue
# 53              F        34244      Blue
# 28              F        38973      Blue
# 46              F        48352      Blue
# 59              F        29573      Blue
# 50              F        15747      Blue
# 42              M        77030      Platinum
# 55              F        11770      Blue
# 40              F        13009      Blue
# 34              M        54825      Blue
# 47              F        14758      Blue
# 28              M        18328      Blue
# 46              F        12892      Blue
# 45              F        24359      Blue
# 41              M        119745     Silver
# 41              F        14975      Blue
# 50              M        75383      Blue
# 65              F        13038      Blue
# 46              F        14975      Blue
# 53              F        20854      Blue
# 42              M        85630      Blue
# 59              M        54088      Blue
# 46              F        11834      Blue
# 57              M        99124      Platinum
# 39              F        19539      Blue
# 53              F        47411      Blue
# 39              F        25090      Blue
# 51              F        35825      Blue
# 48              F        23908      Blue
# 51              M        76189      Blue
# 42              M        58565      Blue
# 48              F        24465      Blue
# 45              M        49194      Blue
# 46              F        23435      Blue
# 44              F        50766      Blue
# 56              M        65168      Blue
# 40              M        59025      Blue
# 36              F        36346      Blue
# 48              F        5525       Blue
# 47              M        82022      Blue
# 54              F        27218      Blue
# 54              F        14541      Blue
# 38              M        115781     Gold
# 40              M        57772      Blue
# 47              M        112414     Gold
# 46              F        38076      Blue
# 48              F        18903      Blue
# 48              F        14975      Blue
# 49              F        14779      Blue
# 45              F        58347      Blue
# 40              F        36132      Blue
# 29              M        68561      Blue
# 41              M        119387     Blue
# 41              F        20045      Blue
# 48              F        14975      Blue
# 43              M        80385      Blue
# 57              F        57764      Blue
# 30              M        70459      Blue
# 56              F        14975      Blue
# 47              F        10703      Blue
# 58              M        90691      Blue
# 46              F        54564      Blue
# 39              F        21658      Blue
# 40              F        43615      Blue
# 31              M        42033      Blue
# 46              F        26207      Blue
# 38              F        19094      Blue
# 49              M        61533      Blue
# 41              F        23857      Blue
# 47              M        62964      Blue
# 44              F        41655      Blue
# 34              F        20416      Blue
# 40              F        14250      Blue
# 44              M        56655      Blue
# 40              M        66119      Blue
# 41              F        14975      Blue
# 44              M        47313      Blue
# 36              F        45256      Blue
# 44              F        23002      Blue
# 40              M        67444      Blue
# 50              F        50345      Blue
# 43              M        49540      Blue
# 44              F        11631      Blue
# 39              F        20254      Blue
# 42              F        52996      Blue
# 41              F        41440      Blue
# 50              M        67686      Blue
# 45              M        71366      Blue
# 49              F        42961      Blue
# 48              M        109992     Platinum
# 51              F        29272      Blue
# 44              F        11335      Blue
# 45              F        14975      Blue
# 37              F        5525       Blue
# 49              F        35358      Blue
# 33              F        10482      Blue
# 44              F        39065      Blue
# 53              F        13789      Blue
# 44              M        69905      Blue
# 44              F        25898      Blue
# 44              F        39948      Blue
# 39              F        59054      Blue
# 53              M        91843      Blue
# 61              F        221853     Gold
# 41              F        36894      Blue
# 39              F        45922      Blue
# 41              M        107722     Blue
# 46              F        24737      Blue
# 38              M        59173      Blue
# 49              M        97244      Blue
# 45              F        189693     Silver
# 57              F        54352      Blue
# 47              M        101520     Blue
# 60              F        36218      Blue
# 58              F        31379      Blue
# 39              F        52746      Blue
# 45              M        59377      Blue
# 39              F        6550       Blue
# 26              F        34497      Blue
# 51              F        10206      Blue
# 42              M        104894     Blue
# 38              M        17090      Blue
# 62              M        59729      Blue
# 59              M        118817     Silver
# 43              M        48695      Blue
# 50              F        35362      Blue
# 40              M        118799     Blue
# 51              M        52383      Blue
# 46              M        73929      Blue
# 59              M        61725      Blue
# 44              F        14975      Blue
# 51              M        112201     Blue
# 50              F        32046      Blue
# 58              F        6550       Blue
# 58              M        166134     Silver
# 50              M        94105      Blue
# 39              F        55025      Blue
# 60              F        38530      Blue
# 45              M        63395      Blue
# 49              F        13297      Blue
# 49              M        97182      Blue
# 49              F        24125      Blue
# 51              M        111534     Blue
# 48              M        70132      Blue
# 56              F        11077      Blue
# 51              M        91474      Blue
# 49              F        11571      Blue
# 31              F        40769      Silver
# 46              F        25690      Blue
# 52              F        55378      Blue
# 37              M        118384     Blue
# 48              F        33087      Blue
# 34              F        14347      Blue
# 39              F        30328      Blue
# 63              F        36424      Blue
# 56              M        79575      Blue
# 39              F        55360      Blue
# 52              M        102142     Silver
# 45              F        51426      Blue
# 46              F        27192      Blue
# 32              M        95787      Blue
# 47              F        14975      Blue
# 53              F        10860      Blue
# 56              M        68885      Blue
# 47              M        54849      Blue
# 51              F        16430      Blue
# 51              M        78519      Blue
# 44              F        40964      Blue
# 60              F        17420      Blue
# 47              M        56188      Blue
# 41              M        97099      Blue
# 59              F        36855      Blue
# 32              F        14975      Blue
# 50              M        105020     Blue
# 59              F        55343      Blue
# 51              F        34427      Blue
# 47              F        32820      Blue
# 38              M        132778     Blue
# 32              M        44612      Blue
# 40              F        44055      Blue
# 47              F        34490      Blue
# 39              M        42198      Blue
# 31              M        111283     Blue
# 31              M        36373      Blue
# 51              F        210347     Blue
# 45              F        14975      Blue
# 52              F        27800      Blue
# 54              M        97859      Blue
# 39              M        10095      Blue
# 52              F        59135      Blue
# 43              F        26410      Blue
# 36              F        56905      Blue
# 52              F        38225      Blue
# 36              F        26185      Blue
# 48              F        40661      Blue
# 41              F        35049      Silver
# 44              M        107870     Blue
# 46              M        59996      Blue
# 46              M        10082      Blue
# 51              F        40513      Blue
# 52              M        58590      Blue
# 36              F        30424      Blue
# ...
# 34              M        53688      Blue
# 32              F        32860      Blue
# 60              F        17624      Silver
# 36              M        85031      Silver
# 49              F        16106      Blue
# 38              M        93055      Blue
# 49              F        38926      Silver
# 57              F        16433      Blue
# 52              F        10514      Blue
# 38              F        14975      Blue
# 48              M        47477      Blue
# 62              M        16461      Blue
# 54              F        31725      Blue
# 48              M        77849      Silver
# 53              F        11540      Blue
# 48              F        48809      Blue
# 61              F        36884      Blue
# 45              M        77935      Blue
# 47              M        67550      Blue
# 50              F        33599      Blue
# 43              M        96647      Blue
# 44              F        18370      Blue
# 45              F        209872     Silver
# 48              F        211378     Silver
# 58              F        22046      Blue
# 46              F        12150      Blue
# 59              F        42593      Blue
# 50              M        43991      Blue
# 41              F        2565       Blue
# 54              F        14975      Gold
# 51              F        14078      Blue
# 38              F        20583      Blue
# 49              F        24721      Blue
# 52              M        107133     Blue
# 43              F        48110      Blue
# 51              F        19529      Blue
# 44              F        15042      Blue
# 31              F        31578      Blue
# 45              M        68316      Blue
# 39              M        90096      Blue
# 56              F        33294      Blue
# 43              F        11727      Blue
# 40              F        23926      Silver
# 40              F        56214      Blue
# 46              F        38823      Blue
# 43              F        15522      Blue
# 39              M        51893      Gold
# 46              F        28732      Blue
# 54              F        10256      Blue
# 29              M        52727      Blue
# 43              M        94932      Blue
# 36              M        61111      Blue
# 46              M        51286      Blue
# 52              M        60799      Blue
# 41              F        170693     Blue
# 59              M        71347      Blue
# 59              F        49413      Blue
# 50              F        50916      Blue
# 43              F        14975      Blue
# 33              F        33045      Blue
# 55              F        41177      Silver
# 51              F        46414      Blue
# 59              F        239639     Platinum
# 43              F        31165      Blue
# 37              M        95558      Blue
# 38              M        47728      Blue
# 46              F        35021      Blue
# 53              M        64697      Blue
# 63              F        7865       Blue
# 57              F        189681     Silver
# 35              M        30585      Blue
# 57              F        17612      Blue
# 41              F        50967      Blue
# 53              F        39639      Blue
# 50              M        91626      Blue
# 43              F        46848      Blue
# 41              F        147098     Blue
# 47              M        79385      Blue
# 50              F        11480      Blue
# 47              M        70983      Silver
# 47              F        1250       Blue
# 45              M        119437     Silver
# 33              F        11841      Silver
# 31              M        68161      Blue
# 53              F        46834      Blue
# 50              F        13970      Blue
# 32              M        234897     Silver
# 38              F        20040      Blue
# 48              F        16168      Blue
# 40              F        30655      Blue
# 49              F        18197      Blue
# 41              F        19506      Blue
# 52              F        179489     Blue
# 39              F        6550       Blue
# 47              M        79692      Blue
# 50              F        5225       Blue
# 50              F        225646     Gold
# 41              F        17290      Blue
# 42              F        33113      Blue
# 35              F        19227      Blue
# 54              F        14975      Blue
# 58              F        32956      Blue
# 57              M        60463      Blue
# 41              F        44767      Gold
# 58              M        68047      Blue
# 37              F        20644      Blue
# 58              F        29573      Blue
# 45              M        45738      Blue
# 48              F        22135      Blue
# 56              M        69818      Blue
# 39              F        50508      Blue
# 60              F        15979      Blue
# 57              F        14975      Blue
# 49              F        37655      Blue
# 50              F        28183      Blue
# 38              F        52914      Blue
# 32              M        64538      Blue
# 55              F        32334      Blue
# 37              F        14975      Blue
# 44              M        55159      Blue
# 60              M        73524      Blue
# 43              M        43842      Blue
# 50              F        14975      Blue
# 44              F        29998      Silver
# 48              F        50528      Blue
# 46              F        14975      Blue
# 45              F        35630      Blue
# 45              M        92084      Blue
# 43              M        96710      Blue
# 51              F        197655     Gold
# 39              M        18361      Blue
# 62              F        38192      Blue
# 36              F        35177      Blue
# 55              M        82924      Blue
# 38              F        31745      Blue
# 40              M        89370      Blue
# 57              F        31547      Silver
# 50              F        29167      Blue
# 40              F        31188      Blue
# 39              F        14975      Silver
# 53              F        25531      Blue
# 42              F        39478      Blue
# 41              F        7865       Blue
# 38              F        12149      Blue
# 35              F        21755      Blue
# 50              M        61269      Blue
# 37              F        14975      Silver
# 44              F        22759      Blue
# 61              M        69776      Blue
# 60              M        50262      Blue
# 47              F        20297      Blue
# 52              M        118907     Blue
# 47              M        16027      Blue
# 48              M        61917      Blue
# 31              M        110407     Blue
# 41              M        114549     Blue
# 39              F        23525      Blue
# 60              F        5225       Blue
# 46              M        107951     Blue
# 63              M        85028      Blue
# 35              F        22611      Blue
# 45              F        10361      Blue
# 53              F        30404      Blue
# 42              F        35729      Blue
# 46              M        174082     Blue
# 59              F        39169      Blue
# 48              M        79337      Blue
# 55              F        27768      Blue
# 40              M        73563      Blue
# 57              M        54925      Blue
# 48              F        34330      Blue
# 54              F        17238      Blue
# 62              M        71592      Blue
# 52              M        120016     Blue
# 36              F        14826      Blue
# 47              M        107673     Blue
# 44              F        26494      Blue
# 41              M        39481      Blue
# 61              F        47873      Blue
# 45              F        18391      Blue
# 52              M        93535      Blue
# 54              F        36659      Blue
# 46              M        28611      Blue
# 45              F        25817      Blue
# 45              F        34750      Blue
# 60              F        31525      Blue
# 53              F        17174      Silver
# 50              F        11481      Blue
# 54              M        48196      Blue
# 42              M        92177      Blue
# 44              F        17872      Blue
# 47              F        228636     Gold
# 45              F        21500      Blue
# 52              F        14975      Blue
# 56              F        18099      Blue
# 60              F        25533      Blue
# 43              F        23321      Blue
# 50              F        14975      Blue
# 57              F        53933      Blue
# 38              M        71813      Blue
# 37              M        101391     Blue
# 39              F        19238      Blue
# 54              F        20025      Blue
# 38              F        14975      Blue
# 41              F        30228      Blue
# 54              M        90267      Blue
# 49              F        14975      Blue
# 37              M        42331      Blue
# 52              M        84276      Blue
# 44              M        180166     Silver
# 45              M        76386      Blue
# 48              M        24968      Blue
# 47              F        50157      Blue
# 49              F        220560     Silver
# 55              F        46004      Blue
# 32              M        48235      Blue
# 44              F        12150      Blue
# 32              F        14975      Blue
# 65              F        18944      Blue
# 46              F        23767      Blue
# 37              F        45603      Blue
# 56              M        110910     Blue
# 55              F        22865      Blue
# 43              M        112250     Blue
# 42              M        193972     Blue
# 50              M        94436      Blue
# 43              F        11481      Blue
# 41              M        201395     Blue
# 54              F        14975      Blue
# 39              F        34349      Blue
# 53              F        31158      Blue
# 35              F        19634      Blue
# 32              F        14384      Blue
# 47              F        52091      Blue
# 52              F        21486      Blue
# 53              F        23918      Blue
# 49              F        31969      Blue
# 52              F        51977      Blue
# 56              M        65329      Silver
# 51              F        20082      Blue
# 41              F        48444      Blue
# 48              M        51947      Blue
# 54              F        42751      Silver
# 61              F        26982      Blue
# 59              F        35689      Blue
# 33              M        76649      Blue
# 48              M        118577     Blue
# 53              F        14975      Blue
# 54              F        37566      Blue
# 52              F        15682      Blue
# 42              F        19999      Blue
# 41              F        18828      Blue
# 33              F        199268     Blue
# 49              F        20200      Blue
# 38              F        28211      Blue
# 43              F        18856      Blue
# 50              F        2565       Blue
# 40              F        10356      Blue
# 57              F        21884      Silver
# 56              F        50459      Blue
# 48              M        58832      Blue
# 40              F        181977     Blue
# 47              F        15725      Blue
# 41              F        13307      Blue
# 54              M        66988      Blue
# 58              F        53476      Blue
# 44              M        109369     Blue
# 44              M        114299     Platinum
# 45              M        79751      Blue
# 45              F        28424      Blue
# 50              M        73686      Blue
# 42              F        13030      Blue
# 45              F        34181      Blue
# 54              F        10378      Blue
# 40              M        26316      Blue
# 51              M        158189     Gold
# 27              M        65252      Blue
# 43              M        66976      Blue
# 43              M        80939      Blue
# 56              M        124133     Blue
# 33              F        39930      Blue
# 47              M        58855      Blue
# 42              F        20788      Blue
# 43              M        69682      Blue
# 56              M        54299      Blue
# 46              M        92731      Blue
# 45              F        16889      Blue
# 45              M        114709     Silver
# 56              F        18481      Blue
# 40              M        79634      Blue
# 56              F        14975      Blue
# 46              F        14975      Blue
# 41              F        48510      Blue
# 46              M        64242      Blue
# 47              F        158698     Blue
# 48              F        39339      Blue
# 42              F        42410      Blue
# 46              M        58149      Blue
# 50              F        40998      Blue
# 54              F        17285      Blue
# 39              M        54181      Blue
# 42              F        228308     Gold
# 48              M        73655      Blue
# 42              F        21390      Blue
#
# Do you want to:
# 1. Try the same filter again
# 2. Go back to main menu
# 0. Quit Program
# Enter 1, 2, or 0:  0
# Thank you for using our customer data explorer. Goodbye!
