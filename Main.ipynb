# %%
# Import the menu system
from Menu import main_menu

def main():
    # Program introduction
    print("\n" + "="*50)
    print("CUSTOMER DATA ANALYSIS PROGRAM".center(50))
    print("="*50)
    print("\nCreated by: H T Sanchitha Nelani Peiris")
    print("Student ID: 103001223")
    print("Course: Applied for AI and Data Science ")
    print("Module: Programming For Problem Solving - COM731 ")
    print("\nThis program provides tools for analyzing customer data")
    print("with filtering capabilities, statistical analysis,")
    print("and data visualization options.")
    print("="*50)
    
    # Get user's name and personalize the welcome
    user_name = input("\nPlease enter your name: ").strip()
    if not user_name:
        user_name = "Guest"
    
    print(f"\nWelcome, {user_name}!")
    print("This program will help you analyze customer credit card data.")
    print("You can choose from three main analysis modules:\n")
    print("1. Task A - Filter and view specific customer data")
    print("2. Task B - Perform statistical analysis")
    print("3. Task C - Generate visualizations")
    print("\nLet's get started!\n")
    
    # Run the main menu
    main_menu()
    
    # Exit message
    print(f"\nThank you for using the program, {user_name}!")
    print("Have a great day!\n")

if __name__ == "__main__":
    main()
# Out:
# ...
#           CUSTOMER DATA ANALYSIS PROGRAM
# ...
#
# Created by: H T Sanchitha Nelani Peiris
# Student ID: 103001223
# Course: Applied for AI and Data Science
# Module: Programming For Problem Solving - COM731
#
# This program provides tools for analyzing customer data
# with filtering capabilities, statistical analysis,
# and data visualization options.
# ...
# Please enter your name:  Neli
# Welcome, Neli!
# This program will help you analyze customer credit card data.
# You can choose from three main analysis modules:
#
# 1. Task A - Filter and view specific customer data
# 2. Task B - Perform statistical analysis
# 3. Task C - Generate visualizations
#
# Let's get started!
#
#
# === CUSTOMER DATA ANALYSIS SYSTEM ===
# 1. Task A - Data Retrieval
# 2. Task B - Data Filtering
# 3. Task C - Data Visualization
# 4. Load Data Files
# 0. Exit Program
# Enter your choice (0-4):  1
# Please load the data first using option 4
#
# === CUSTOMER DATA ANALYSIS SYSTEM ===
# 1. Task A - Data Retrieval
# ...
