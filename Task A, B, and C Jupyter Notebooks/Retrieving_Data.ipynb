# %%
import csv

# Function to load the CSV file and store its content in a list
def load_csv_file():
    csv_list = []  # Initialize an empty list to store the CSV data
    while True:
        # Prompt user to enter the file name or quit the program
        file_name = input("Enter the CSV file name or enter 'q' to quit the program: ")
        
        if file_name.lower() == 'q':  # If user inputs 'q', exit the function
            print("Exiting the program.")
            return None
        
        try:
            # Try to open the CSV file with UTF-8 encoding
            with open(file_name, 'r', encoding='UTF-8') as csv_file:
                csv_list.clear()  # Clear any existing data in the list
                for line in csv_file:
                    # Split each line by commas and add it to the list
                    csv_list.append(line.strip().split(','))
            print("CSV file loaded successfully.")
            return csv_list  # Return the populated CSV list
        except FileNotFoundError as e:
            # If file is not found, print an error message
            print(f"File does not exist: {e}")

# ------------------------------
# Task c1: Filter and display data based on card category
# ------------------------------
def filter_by_card_category(csv_list):
    print("\nRetrieve client number, gender, education level, and income based on card category.")
    card_options = {'1': 'BLUE', '2': 'PLATINUM', '3': 'GOLD', '4': 'SILVER'}

    while True:
        print("\nSelect a Card Category:")
        for key, value in card_options.items():
            print(f"{key}. {value.capitalize()}")
        print("0. Quit to Main Menu")  # Changed from 'q' to '0'

        user_input = input("Enter your choice (1-4) or '0': ").strip()

        if user_input == '0':
            return 'quit'
        if user_input not in card_options:
            print("Invalid option. Try again.")
            continue

        selected_category = card_options[user_input]
        card_category = []

        for row in csv_list[1:]:
            if row[15].upper() == selected_category:
                card_category.append([row[0], row[2], row[4], row[13]])

        if card_category:
            print(f"\n{'Client_Num':<12} {'Gender':<8} {'Education_Level':<15} {'Income':<10}")
            print("_" * 45)
            for item in card_category:
                print(f"{item[0]:<12} {item[1]:<8} {item[2]:<15} {item[3]:<10}")
        else:
            print(f"No data found for the category '{selected_category}'.")

        again = input("\nTry another card category? (Yes/No): ").strip().lower()
        if again != 'yes':
            return

# ------------------------------
# Task c2: Filter and display data based on state
# ------------------------------
def filter_by_state(csv_list):
    print("\nRetrieve the age, gender, income, and credit card category of customers based on state of residence.")

    while True:
        print("\nType the State abbreviation (e.g., NY, TX, CA) or '0' to quit to Main Menu.")  # Changed from 'q' to '0'
        user_input = input("Enter state abbreviation: ").strip().upper()

        if user_input == '0':
            return 'quit'

        state_data = []

        for row in csv_list[1:]:
            if row[6].upper() == user_input:
                state_data.append([row[1], row[2], row[13], row[15]])

        if state_data:
            print(f"\n{'Customer_Age':<15} {'Gender':<8} {'Income':<10} {'Card_Category':<15}")
            print("-" * 50)
            for item in state_data:
                print(f"{item[0]:<15} {item[1]:<8} {item[2]:<10} {item[3]:<15}")
        else:
            print(f"No data found for state '{user_input}'.")

        again = input("\nTry another state? (Yes/No): ").strip().lower()
        if again != 'yes':
            return

# ------------------------------
# Task c3: Filter by marital status and number of dependents
# ------------------------------
def filter_by_marital_and_dependents(csv_list):
    print("\nRetrieve age, gender, education level, and job of customers based on marital status and dependents.")

    while True:
        marital_options = {'1': 'Single', '2': 'Married', '3': 'Unknown'}
        print("\nSelect Marital Status:")
        for key, value in marital_options.items():
            print(f"{key}. {value}")
        print("0. Quit to Main Menu")  # Changed from 'q' to '0'

        user_input = input("Enter your choice (1-3) or '0': ").strip()

        if user_input == '0':
            return 'quit'
        if user_input not in marital_options:
            print("Invalid option. Try again.")
            continue

        selected_marital = marital_options[user_input]
        marital_status = []

        for row in csv_list[1:]:
            if row[5].lower() == selected_marital.lower() and int(row[3]) > 3:
                marital_status.append([row[1], row[2], row[4], row[12]])

        if marital_status:
            print(f"\n{'Age':<15} {'Gender':<10} {'Education Level':<15} {'Customer Job':<10}")
            print("_" * 55)
            for item in marital_status:
                print(f"{item[0]:<15} {item[1]:<10} {item[2]:<15} {item[3]:<10}")
        else:
            print(f"No data found for marital status '{selected_marital}' with more than 3 dependents.")

        again = input("\nTry another marital status? (Yes/No): ").strip().lower()
        if again != 'yes':
            return
            
# ------------------------------
# Task c4: Filter based on loan status and age above 25
# ------------------------------
def filter_by_loan_and_age(csv_list):
    print("\nRetrieve the job, income, car ownership, and gender of customers older than 25 based on loan status.")

    while True:
        loan_options = {'1': 'yes', '2': 'no'}
        print("\nSelect Loan Status:")
        for key, value in loan_options.items():
            print(f"{key}. {value.capitalize()}")
        print("0. Quit to Main Menu")  # Changed from 'q' to '0'

        user_input = input("Enter your choice (1-2) or '0': ").strip()

        if user_input == '0':
            return 'quit'
        if user_input not in loan_options:
            print("Invalid option. Try again.")
            continue

        selected_loan = loan_options[user_input]
        loan_and_gender = []

        for row in csv_list[1:]:
            if row[10].lower() == selected_loan and int(row[1]) > 25:
                loan_and_gender.append([row[12], row[13], row[8], row[2]])

        if loan_and_gender:
            print(f"\n{'Customer_Job':<15} {'Income':<10} {'Car_Owner':<8} {'Gender':<10}")
            print("-" * 45)
            for item in loan_and_gender:
                print(f"{item[0]:<15} {item[1]:<10} {item[2]:<8} {item[3]:<10}")
        else:
            print(f"No data found for loan status '{selected_loan}' and age > 25.")

        again = input("\nTry another loan status? (Yes/No): ").strip().lower()
        if again != 'yes':
            return

# -----------------------------
# Main Menu Function 
# -----------------------------

def main():
    csv_list = None
    while True:
        if csv_list is None:
            csv_list = load_csv_file()  # Load CSV file if not already loaded
            if csv_list is None:  # If loading fails, break the loop
                break

        # Display menu options for the user to filter data
        print("\nSelect an option to filter data:")
        print("1. Filter by Card Category")
        print("2. Filter by State")
        print("3. Filter by Marital Status and Dependents")
        print("4. Filter by Loan Status and Age")
        print("0. Quit Program")

        choice = input("Enter your choice (1-4) or '0': ").strip()

        if choice == '1':
            result = filter_by_card_category(csv_list)  # Call function to filter by card category
        elif choice == '2':
            result = filter_by_state(csv_list)  # Call function to filter by state
        elif choice == '3':
            result = filter_by_marital_and_dependents(csv_list)  # Call function to filter by marital status and dependents
        elif choice == '4':
            result = filter_by_loan_and_age(csv_list)  # Call function to filter by loan status and age
        elif choice == '0':
            print("\nThank you for using our customer data explorer. Goodbye!")
            break  # Exit the program
        else:
            print("Invalid choice. Please try again.")
            continue

        if result == 'quit':  # If user selects to quit, return to main menu
            print("Returning to main menu.\n")
# -----------------------------
# Run the main function
# -----------------------------

if __name__ == "__main__":
    main()
# Out:
# Enter the CSV file name or enter 'q' to quit the program:  credit_card_customers.csv
# CSV file loaded successfully.
#
# Select an option to filter data:
# 1. Filter by Card Category
# 2. Filter by State
# 3. Filter by Marital Status and Dependents
# 4. Filter by Loan Status and Age
# 0. Quit Program
# Enter your choice (1-4) or '0':  1
# Retrieve client number, gender, education level, and income based on card category.
#
# Select a Card Category:
# 1. Blue
# 2. Platinum
# 3. Gold
# 4. Silver
# q. Quit to Main Menu
# Enter your choice (1-4) or 'q':  1
# Client_Num   Gender   Education_Level Income
# _____________________________________________
# 708082083    F        Uneducated      202326
# 708083283    F        Unknown         5225
# 708084558    F        Unknown         14235
# 708085458    M        Uneducated      45683
# 708086958    M        Graduate        59279
# 708095133    F        High School     14254
# 708098133    F        Graduate        14975
# 708099183    F        Uneducated      31982
# 708100533    M        High School     86668
# 708104658    F        Post-Graduate   33625
# 708108333    F        Graduate        14975
# 708112008    F        Graduate        14975
# 708113208    M        High School     59416
# 708117933    F        Graduate        28122
# 708119658    F        Graduate        29021
# 708121908    F        Graduate        20632
# 708125733    F        Graduate        57168
# 708128733    M        Graduate        89954
# 708129933    F        Uneducated      53762
# 708132783    F        Unknown         45476
# 708134283    M        Graduate        14975
# 708136908    M        Doctorate       72878
# 708139833    F        Unknown         25667
# 708145908    M        Graduate        47224
# 708147108    F        Graduate        25341
# 708148158    M        Doctorate       53644
# 708151008    F        Uneducated      27423
# 708152358    M        Graduate        110014
# 708153558    M        Graduate        109186
# 708154833    F        Graduate        25835
# 708155733    F        Graduate        11345
# 708158133    F        Uneducated      23215
# 708160008    M        Graduate        103581
# 708161133    F        Unknown         44555
# 708162558    F        Graduate        12381
# 708170508    F        Graduate        14975
# 708171858    F        Graduate        30586
# 708173433    F        Graduate        28367
# 708174708    F        Graduate        15355
# 708176208    F        Uneducated      53428
# 708178608    F        Unknown         54304
# 708185208    F        Doctorate       20100
# 708186933    F        Unknown         24295
# 708190158    F        Unknown         32103
# 708193008    F        Graduate        14975
# 708197358    M        Uneducated      107887
# 708204033    M        Graduate        51233
# 708205083    M        Graduate        79516
# 708207783    M        Graduate        73959
# 708208758    F        Doctorate       23377
# 708211383    F        Uneducated      44883
# 708212658    F        High School     16041
# 708216108    F        Unknown         24221
# 708217758    F        Graduate        14975
# 708219108    M        Graduate        102561
# 708219858    F        Graduate        56697
# 708222558    F        Uneducated      53022
# 708223383    F        Uneducated      32013
# 708224133    M        Graduate        62192
# 708225483    F        Post-Graduate   55061
# 708229308    M        Uneducated      100839
# 708231183    F        Uneducated      31127
# 708234558    M        High School     67827
# 708238833    F        High School     12994
# 708241233    F        Graduate        5225
# 708242283    F        Unknown         35755
# 708243483    F        High School     24156
# 708244458    M        Graduate        37888
# 708249708    F        Graduate        14975
# 708252108    F        Graduate        49229
# 708253458    M        Unknown         81622
# 708254733    M        Graduate        95152
# 708255633    F        Graduate        35666
# 708260208    F        Graduate        57686
# 708266883    F        Graduate        25423
# 708267858    F        High School     21500
# 708269583    F        High School     47653
# 708272808    F        Unknown         38560
# 708273858    F        Graduate        41203
# 708276183    F        Graduate        14975
# 708281433    F        Uneducated      43626
# 708285108    M        Unknown         131861
# 708286683    M        Graduate        83306
# 708288108    M        Graduate        1250
# 708291633    M        Unknown         92894
# 708292833    F        Graduate        32170
# 708295533    M        Unknown         10119
# 708296883    F        Graduate        8250
# 708298233    F        High School     15092
# 708300483    F        Doctorate       1250
# 708301683    M        High School     110415
# 708303108    M        High School     86574
# 708307533    M        Post-Graduate   51165
# 708313608    F        Graduate        21659
# 708314808    F        Uneducated      14975
# 708316008    F        Unknown         15806
# 708319908    M        Graduate        116230
# 708323208    F        Doctorate       24058
# 708324483    M        Unknown         61485
# 708330858    F        Graduate        1250
# 708332808    F        Uneducated      166923
# 708334158    F        Uneducated      34512
# 708337683    M        Graduate        42779
# 708338958    M        High School     42334
# 708340758    M        Graduate        111220
# 708341958    M        Unknown         64665
# 708344358    F        High School     11638
# 708347583    F        Graduate        16112
# 708354858    M        Graduate        111730
# 708355683    F        Unknown         34013
# 708357183    F        Doctorate       38164
# 708360108    M        Uneducated      82412
# 708361833    F        Graduate        39861
# 708367908    M        Graduate        60037
# 708371733    M        High School     86281
# 708373083    F        High School     20495
# 708375858    F        Post-Graduate   57624
# 708376983    F        Graduate        21828
# 708378108    M        Uneducated      71834
# 708382083    F        Unknown         30259
# 708384033    F        High School     28037
# 708386958    F        Graduate        19006
# 708387933    M        High School     165306
# 708390633    M        High School     53965
# 708393633    M        Unknown         71640
# 708394908    F        Post-Graduate   45818
# 708396033    M        Unknown         119585
# 708397008    F        High School     57821
# 708398283    F        High School     12775
# 708399858    M        Unknown         76565
# 708402333    M        Unknown         78127
# 708404883    F        Unknown         32229
# 708406083    M        Unknown         95876
# 708412758    F        Unknown         23378
# 708414033    F        Graduate        41115
# 708416433    F        Unknown         28601
# 708419733    M        Graduate        76246
# 708421833    F        High School     6550
# 708423933    F        Doctorate       35491
# 708426483    F        Uneducated      38451
# 708427908    M        Graduate        72412
# 708431433    F        Graduate        14633
# 708433683    M        Graduate        61002
# 708434733    F        Unknown         10627
# 708438033    M        High School     30828
# 708442158    F        Graduate        42377
# 708445608    F        Uneducated      20389
# 708446808    F        High School     20281
# 708447858    F        High School     200276
# 708450033    M        Unknown         97684
# 708451233    F        Graduate        40785
# 708453408    F        Graduate        41039
# 708455883    F        Graduate        6550
# 708459633    F        Uneducated      14975
# 708469533    F        Uneducated      38273
# 708472008    M        Graduate        105522
# 708473133    M        Unknown         69787
# 708474333    M        Graduate        108894
# 708476808    F        Doctorate       5525
# 708478233    F        Uneducated      58670
# 708480333    F        Uneducated      23891
# 708483708    M        Unknown         58122
# 708486033    F        Doctorate       15671
# 708488208    F        Uneducated      23898
# 708489258    F        Doctorate       38817
# 708491508    F        Graduate        43716
# 708492558    F        Graduate        6550
# 708494583    F        Post-Graduate   41132
# 708496833    M        Graduate        117520
# 708498033    F        High School     32495
# 708501783    F        High School     17340
# 708504783    F        Uneducated      37815
# 708506508    M        Uneducated      83535
# 708507483    M        Unknown         78913
# 708508758    F        Uneducated      1250
# 708510858    F        High School     214404
# 708511983    M        Graduate        45977
# 708513183    F        High School     34616
# 708514383    F        Uneducated      57484
# 708515358    F        High School     53906
# 708516558    F        Graduate        52148
# 708519108    F        Unknown         20597
# 708522033    F        Uneducated      198343
# 708525108    M        High School     50792
# 708528483    F        Graduate        13010
# 708532308    F        Unknown         34149
# 708534033    M        Unknown         75578
# 708535158    M        Graduate        114717
# 708536283    F        Graduate        31226
# 708538608    F        Uneducated      48968
# 708539583    F        Post-Graduate   46675
# 708542283    M        Graduate        60253
# 708543258    F        Doctorate       20631
# 708545058    M        High School     94345
# 708549033    M        High School     90458
# 708551508    M        Uneducated      87971
# 708553008    M        Doctorate       74928
# 708557358    F        Graduate        18357
# 708558408    M        Unknown         41925
# 708559533    M        High School     62768
# 708560733    M        High School     75192
# 708563433    F        Uneducated      14975
# 708568983    M        Unknown         111225
# 708575058    F        Post-Graduate   36188
# 708577308    M        Graduate        14975
# 708580908    F        Graduate        12686
# 708582858    F        Doctorate       33801
# 708584208    F        Graduate        26226
# 708585933    M        Unknown         55576
# 708588408    M        High School     61579
# 708590658    F        High School     14975
# 708593883    F        Doctorate       16316
# 708595158    F        Uneducated      26447
# 708596283    F        Graduate        32924
# 708597558    M        Doctorate       45984
# 708600033    M        Unknown         87531
# 708602283    F        Unknown         45701
# 708606633    M        Graduate        18114
# 708611733    M        Doctorate       73096
# 708614058    M        Unknown         44044
# 708615183    M        Graduate        68693
# 708618933    F        Graduate        35767
# 708620283    F        Graduate        23554
# 708621408    F        High School     52557
# 708623283    F        Graduate        21274
# 708626058    M        Unknown         50213
# 708633783    F        Graduate        16244
# 708635058    M        Graduate        78702
# 708637758    F        Unknown         38269
# 708642708    M        Post-Graduate   14975
# 708644208    F        Uneducated      36638
# 708646233    F        Uneducated      39538
# 708651933    F        Graduate        25413
# 708652908    M        Uneducated      65425
# 708653958    F        High School     30594
# 708655983    F        Graduate        12264
# 708657033    F        Unknown         43330
# 708660408    F        Graduate        27897
# 708664008    F        High School     10286
# 708665133    F        High School     47309
# 708666258    F        Graduate        13305
# 708668283    F        High School     16829
# 708669408    M        High School     72173
# 708670608    M        Doctorate       94093
# 708671733    M        Doctorate       50004
# 708672708    F        Uneducated      46921
# 708679383    F        Graduate        15566
# 708680583    M        Uneducated      86542
# 708681708    F        Uneducated      19558
# 708682908    M        Graduate        115771
# 708684108    F        Uneducated      23705
# 708688608    F        Post-Graduate   14975
# 708689958    M        Post-Graduate   76589
# 708692583    F        High School     25474
# 708694983    F        Graduate        183156
# 708697983    M        Graduate        116731
# 708699108    M        Graduate        83739
# 708701358    M        High School     47266
# 708702258    F        Graduate        20731
# 708703308    F        Graduate        23108
# 708704433    F        Uneducated      32691
# 708705783    F        Uneducated      30977
# 708706833    F        High School     28042
# 708707808    F        Graduate        37378
# 708708858    F        Uneducated      29521
# 708711483    F        Unknown         14975
# 708712833    M        Graduate        64708
# 708720558    M        High School     41858
# 708722583    F        Graduate        34283
# 708723858    F        Graduate        43493
# 708724908    F        Unknown         50635
# 708726708    F        Uneducated      23265
# 708727983    F        Doctorate       34410
# 708731658    F        Graduate        14975
# 708733983    F        High School     21900
# 708735183    F        Uneducated      24977
# 708736608    F        Unknown         21586
# 708740808    F        Graduate        33749
# 708741633    F        Graduate        15508
# 708744933    F        Graduate        17205
# 708745983    M        High School     74175
# 708747708    F        Graduate        28863
# 708748833    M        Graduate        117419
# 708753633    M        Graduate        63794
# 708754833    M        Unknown         69537
# 708757233    F        Graduate        40618
# 708758658    M        Graduate        45996
# 708759408    F        Post-Graduate   201292
# 708760458    F        Doctorate       40495
# 708761733    M        Graduate        61406
# 708765933    M        High School     82220
# 708768258    M        Unknown         73891
# 708773583    F        Graduate        46820
# 708774708    M        Uneducated      43782
# 708776658    M        Post-Graduate   62818
# 708780783    M        Graduate        76257
# 708784083    F        Graduate        57111
# 708784908    M        Unknown         62468
# 708788583    F        Post-Graduate   14975
# 708790833    F        Unknown         9535
# 708793008    F        Graduate        23521
# 708794133    F        Doctorate       35416
# 708796458    F        High School     34232
# 708797583    F        Uneducated      30135
# 708798483    F        Uneducated      29848
# 708799983    F        Graduate        14975
# 708801108    F        Graduate        21709
# 708804633    F        Uneducated      33335
# 708807483    F        Unknown         43340
# 708809283    F        Unknown         27044
# 708811233    F        Graduate        19789
# 708812133    F        Graduate        50549
# 708816408    F        Unknown         34492
# 708817608    F        Uneducated      53960
# 708818508    F        Uneducated      59846
# 708820308    F        Uneducated      11956
# 708822783    M        High School     81981
# 708823908    F        Doctorate       55237
# 708824958    F        Unknown         55745
# 708826158    M        High School     115410
# 708828258    F        Unknown         11974
# 708829758    F        High School     44199
# 708831858    F        High School     18429
# 708833133    F        High School     20382
# 708834483    F        Uneducated      15554
# 708837858    M        Unknown         61806
# 708838908    F        Uneducated      35361
# 708841233    M        Graduate        111748
# 708846183    F        Graduate        47375
# 708848208    M        Graduate        54203
# 708849858    F        Graduate        40306
# 708856983    F        Doctorate       1250
# 708859158    F        Doctorate       58286
# 708860358    F        Uneducated      14975
# 708862233    M        Doctorate       94935
# 708864708    F        Unknown         13428
# 708866133    M        Graduate        173245
# 708867408    F        Uneducated      20717
# 708868233    F        Uneducated      2565
# 708869283    M        Graduate        38381
# 708870408    M        Post-Graduate   55954
# 708874533    F        Graduate        1250
# 708877458    M        Graduate        110092
# 708878508    F        Uneducated      14975
# 708879483    M        Graduate        89752
# 708880683    M        Graduate        138234
# 708881583    M        High School     116501
# 708884658    M        Uneducated      79857
# 708885558    F        Graduate        23755
# 708886533    M        Graduate        58619
# 708887433    F        Uneducated      35079
# 708888633    F        Graduate        31826
# 708890133    M        High School     73068
# 708890958    F        Graduate        54491
# 708892833    F        Graduate        1250
# 708895158    F        Uneducated      12604
# 708897408    M        High School     75347
# 708899283    M        High School     85352
# 708900408    F        Doctorate       59307
# 708902883    F        Doctorate       36679
# 708905733    M        Post-Graduate   105037
# 708907833    M        Unknown         108540
# 708911508    F        Graduate        37495
# 708913233    F        Graduate        16076
# 708916083    F        Uneducated      28751
# 708917133    M        Unknown         65396
# 708918558    F        Unknown         34367
# 708923658    M        High School     63958
# 708924783    F        Unknown         47867
# 708927108    F        Uneducated      6550
# 708928008    F        Graduate        48210
# 708928908    M        Graduate        94220
# 708931908    F        Uneducated      14975
# 708937608    M        Uneducated      69882
# 708938508    F        Graduate        17366
# 708944958    M        Unknown         70868
# 708946008    F        Unknown         27577
# 708947208    F        High School     31006
# 708949908    F        Graduate        21137
# 708952758    M        Uneducated      83512
# 708953883    F        Unknown         2565
# 708957183    F        Post-Graduate   23360
# 708959583    F        Post-Graduate   37173
# 708960858    M        Graduate        78272
# 708963258    M        High School     114990
# 708964683    M        Graduate        172935
# 708967608    F        Unknown         5525
# 708968733    M        High School     109128
# 708969633    M        Graduate        68004
# 708971583    F        Post-Graduate   14897
# 708972783    F        Graduate        25056
# 708976908    F        Graduate        22074
# 708980283    F        Uneducated      23048
# 708982158    F        Uneducated      185296
# 708983658    F        Graduate        5225
# 708989358    M        Graduate        60076
# 708992733    M        High School     77169
# 708995283    M        Graduate        82470
# 708996708    F        High School     219327
# 708997833    M        Graduate        48602
# 708998583    M        Uneducated      51569
# 709000008    F        Uneducated      21170
# 709005633    F        High School     21675
# 709007883    M        High School     172725
# 709008708    M        Unknown         113270
# 709009833    M        Unknown         71397
# 709012083    F        High School     20130
# 709014558    F        Unknown         59739
# 709017258    F        High School     33205
# 709019283    M        Graduate        108579
# 709022883    F        Post-Graduate   55531
# 709025583    F        Unknown         6550
# 709028208    F        High School     36669
# 709029408    F        High School     14975
# 709035708    F        Graduate        16430
# 709039533    F        High School     43162
# 709040508    F        Graduate        24111
# 709042908    F        High School     23530
# 709044183    F        Uneducated      47088
# 709045683    M        High School     45314
# 709051533    M        Graduate        87414
# 709052883    M        Graduate        100498
# 709054083    M        Graduate        79546
# 709056558    F        High School     19817
# 709058808    F        Graduate        14975
# 709061658    M        Uneducated      67532
# 709064208    F        Uneducated      23748
# 709065483    M        High School     108221
# 709068183    M        High School     74888
# 709071408    M        Graduate        86899
# 709074108    F        Post-Graduate   32487
# 709075533    M        Doctorate       115365
# 709077933    M        Post-Graduate   63667
# 709078908    M        Graduate        85957
# 709079883    F        High School     31902
# 709080783    M        Graduate        75402
# 709081683    F        High School     53694
# 709082808    M        Unknown         92816
# 709085358    F        Uneducated      29488
# 709086933    F        Unknown         53739
# 709087983    M        Graduate        90136
# 709096908    F        Graduate        17285
# 709098108    M        Graduate        76611
# 709100283    F        Graduate        32797
# 709101258    F        Graduate        23073
# 709102458    F        Uneducated      30585
# 709103358    F        Unknown         6550
# 709106358    F        Unknown         2565
# 709108533    F        Post-Graduate   201510
# 709110633    F        Unknown         11997
# 709112508    F        Graduate        22762
# 709117533    F        High School     14975
# 709120008    M        Unknown         10194
# 709121283    F        Unknown         14975
# 709122483    F        Unknown         18306
# 709123908    M        Doctorate       82618
# 709124883    M        Post-Graduate   96537
# 709126833    F        Unknown         50852
# 709127808    F        Uneducated      38043
# 709131033    M        Unknown         48929
# 709134333    M        Doctorate       73655
# 709137558    M        Uneducated      74271
# 709140858    M        Graduate        93790
# 709143183    F        Uneducated      29424
# 709145958    F        Uneducated      14975
# 709149408    F        Uneducated      25885
# 709150608    F        High School     31030
# 709153008    M        High School     74069
# 709157133    F        Doctorate       14975
# 709158333    M        Unknown         55000
# 709161108    F        Graduate        14975
# 709164408    F        High School     1250
# 709165533    M        Uneducated      57981
# 709166883    F        Graduate        50812
# 709169133    M        Uneducated      47113
# 709170108    F        Graduate        14975
# 709171308    M        Graduate        126358
# 709173108    F        Graduate        2565
# 709175208    M        Post-Graduate   74162
# 709176108    M        Graduate        69680
# 709178733    F        Unknown         24804
# 709179708    F        Doctorate       39397
# 709183683    F        Unknown         19461
# 709185108    F        Unknown         16051
# 710084883    F        High School     33915
# 710086308    M        High School     73962
# 710088483    F        Unknown         36022
# 710090133    F        Graduate        44956
# 710090958    F        Uneducated      52717
# 710092683    F        Graduate        16725
# 710094108    M        Graduate        95965
# 710096658    F        Graduate        23257
# 710098233    M        Graduate        66212
# 710099358    M        Doctorate       86420
# 710102208    M        High School     63887
# 710103558    F        Graduate        12373
# 710108133    F        Graduate        11588
# 710109633    F        Graduate        14975
# 710110683    M        Uneducated      80840
# 710111733    F        Unknown         12445
# 710112933    F        Post-Graduate   30206
# 710115108    M        Graduate        68950
# 710116833    F        Graduate        32073
# 710119233    F        Unknown         52811
# 710120358    F        Graduate        23844
# 710125608    M        Unknown         76846
# 710129283    F        High School     33675
# 710133858    F        High School     51900
# 710135058    F        Graduate        14975
# 710136258    F        High School     32823
# 710138883    F        Unknown         16670
# 710141208    F        High School     128211
# 710142258    M        Graduate        73371
# 710149008    F        Graduate        22329
# 710150208    F        Graduate        43253
# 710153583    M        Graduate        118381
# 710155158    M        Graduate        119274
# 710155983    M        Unknown         115203
# 710157108    M        Graduate        71764
# 710159658    F        Graduate        27454
# 710161083    M        Graduate        101185
# 710162133    M        Graduate        117903
# 710163633    M        Post-Graduate   89211
# 710164683    F        Unknown         24132
# 710166783    M        High School     56215
# 710170758    M        Graduate        113257
# 710175783    F        Graduate        56950
# 710180958    F        Uneducated      14975
# 710182383    F        Uneducated      39474
# 710183283    M        Graduate        90708
# 710186958    M        Graduate        62207
# 710188308    M        High School     86061
# 710190858    M        High School     142186
# 710192283    M        Graduate        116314
# 710194683    F        Graduate        25503
# 710197308    F        Graduate        50003
# 710201058    M        Uneducated      53374
# 710202783    F        Unknown         12846
# 710207208    M        Uneducated      126094
# 710208633    F        Unknown         15540
# 710211783    F        High School     24455
# 710213508    M        Unknown         115680
# 710218233    F        High School     35185
# 710219658    M        Graduate        71892
# 710226708    M        Uneducated      69115
# 710227908    F        Graduate        32887
# 710229333    F        Graduate        42568
# 710231433    F        Uneducated      36968
# 710233683    F        Graduate        14975
# 710237283    M        High School     155097
# 710241858    F        Uneducated      20577
# 710243208    M        Graduate        80933
# 710248233    F        Uneducated      36936
# 710251608    F        Uneducated      14397
# 710255208    F        Unknown         19414
# 710256708    F        Graduate        30183
# 710257683    M        Graduate        66678
# 710260983    M        High School     112996
# 710263608    F        Graduate        22647
# 710267583    F        Post-Graduate   45172
# 710268858    F        High School     35216
# 710273658    F        Unknown         33313
# 710277183    F        Doctorate       57568
# 710278458    F        Doctorate       14975
# 710279508    F        High School     14975
# 710280558    F        High School     9535
# 710284233    F        Graduate        27492
# 710287533    F        High School     23783
# 710288883    M        High School     91552
# 710289783    F        Graduate        29411
# 710292333    F        Graduate        30862
# 710294808    M        High School     65840
# 710295858    M        Graduate        110796
# 710297133    M        Graduate        38051
# 710299608    F        Uneducated      2565
# 710300733    M        Post-Graduate   140591
# 710303208    F        Uneducated      207019
# ...
# Selfemployeed   68104      yes      M
# Selfemployeed   14975      yes      F
# Blue-collar     58406      no       F
# Selfemployeed   20064      yes      F
# Selfemployeed   14975      yes      F
# Selfemployeed   5525       no       F
# Businessman     53933      yes      F
# Govt            32356      no       F
# Govt            50719      no       F
# Blue-collar     101744     no       M
# White-collar    50429      no       M
# Businessman     97323      no       M
# Blue-collar     67384      no       M
# Selfemployeed   14975      no       F
# Retirees        71813      yes      M
# Selfemployeed   14975      no       F
# Govt            82242      no       M
# Retirees        19238      no       F
# Govt            27725      yes      F
# White-collar    42413      no       M
# Businessman     219600     no       M
# White-collar    48514      no       M
# Blue-collar     66674      no       M
# Blue-collar     20025      yes      F
# Retirees        61144      yes      M
# White-collar    95193      no       M
# Selfemployeed   14975      yes      F
# Selfemployeed   14975      no       F
# Selfemployeed   73914      no       M
# Govt            45787      yes      F
# White-collar    19589      no       F
# Selfemployeed   42600      yes      M
# Selfemployeed   14975      no       F
# Retirees        100687     no       M
# Selfemployeed   47727      yes      M
# Selfemployeed   27581      no       F
# White-collar    42331      no       M
# Businessman     84276      no       M
# Blue-collar     50533      no       F
# Blue-collar     23819      no       F
# Selfemployeed   55798      yes      F
# Selfemployeed   6550       no       F
# Selfemployeed   33034      no       F
# Govt            37893      yes      F
# Govt            24386      no       F
# Selfemployeed   47379      no       F
# Businessman     157422     yes      M
# Businessman     18724      no       M
# Blue-collar     47902      no       F
# Retirees        76386      yes      M
# Selfemployeed   41765      no       M
# Selfemployeed   73530      yes      M
# Govt            65572      yes      M
# Businessman     50157      no       F
# White-collar    74090      yes      M
# Blue-collar     25848      no       F
# Selfemployeed   14975      yes      F
# Businessman     220560     no       F
# White-collar    123224     no       M
# Selfemployeed   14975      yes      F
# Govt            107063     no       M
# Blue-collar     48433      yes      M
# Govt            35198      no       F
# Retirees        38493      no       F
# White-collar    110689     yes      M
# Govt            45800      yes      M
# Blue-collar     59790      yes      M
# Selfemployeed   14975      yes      F
# White-collar    24687      no       F
# Govt            102712     yes      M
# Selfemployeed   12150      no       F
# Retirees        83442      yes      M
# Retirees        63800      yes      M
# Businessman     26752      no       F
# Selfemployeed   14975      no       F
# Businessman     66838      no       M
# Govt            78545      yes      M
# Govt            107360     yes      M
# Selfemployeed   11380      yes      F
# White-collar    76627      no       M
# White-collar    34812      yes      F
# Selfemployeed   67795      no       M
# Govt            39479      no       F
# Selfemployeed   14975      yes      F
# White-collar    20550      no       F
# Selfemployeed   11102      yes      F
# Retirees        18944      no       F
# Retirees        23767      yes      F
# White-collar    45603      yes      F
# Selfemployeed   14975      yes      F
# White-collar    125097     no       M
# Businessman     179701     yes      F
# White-collar    90138      no       M
# Businessman     29760      no       F
# Blue-collar     110910     yes      M
# Govt            22865      no       F
# Selfemployeed   14975      no       F
# Businessman     48544      no       M
# Govt            112250     yes      M
# Retirees        19464      no       M
# Blue-collar     63428      yes      M
# Businessman     72500      no       M
# Selfemployeed   11574      yes      F
# White-collar    94436      no       M
# Selfemployeed   14975      no       F
# Govt            44960      no       F
# Businessman     201395     no       M
# Blue-collar     14505      no       F
# Govt            44180      yes      F
# Selfemployeed   6550       yes      F
# Govt            99645      no       M
# Businessman     183148     yes      M
# Businessman     173151     yes      M
# White-collar    100752     no       M
# Selfemployeed   14975      no       F
# Govt            26996      no       F
# Govt            34349      no       F
# Retirees        31158      yes      F
# Retirees        48973      no       M
# Selfemployeed   5225       no       F
# White-collar    19634      no       F
# Selfemployeed   74495      yes      M
# Retirees        15603      yes      F
# Businessman     53114      yes      F
# Retirees        103369     yes      M
# Blue-collar     37301      no       F
# Selfemployeed   61430      no       M
# Selfemployeed   14384      yes      F
# Businessman     15632      yes      F
# Businessman     102275     yes      M
# White-collar    52091      no       F
# Govt            21486      yes      F
# Blue-collar     39867      no       F
# White-collar    25100      no       F
# Selfemployeed   74349      yes      M
# Blue-collar     67483      yes      M
# White-collar    141564     yes      F
# Selfemployeed   23918      no       F
# White-collar    31969      no       F
# Businessman     112346     yes      M
# Blue-collar     51977      no       F
# Selfemployeed   14975      yes      F
# Blue-collar     13237      no       F
# White-collar    106625     no       M
# Blue-collar     13236      no       F
# Blue-collar     13185      yes      F
# Blue-collar     115732     no       M
# White-collar    65329      yes      M
# Blue-collar     25397      yes      F
# White-collar    64026      no       M
# Selfemployeed   20082      no       F
# Govt            49607      yes      F
# Retirees        59578      yes      M
# White-collar    51947      no       M
# White-collar    35216      yes      F
# Blue-collar     115815     yes      M
# White-collar    91523      no       M
# Businessman     95448      no       M
# Govt            35689      yes      F
# Retirees        47548      no       M
# Businessman     153063     no       M
# White-collar    76649      yes      M
# White-collar    118577     no       M
# Selfemployeed   14975      no       F
# Selfemployeed   14975      no       F
# Govt            74615      no       M
# Businessman     37086      yes      F
# Businessman     15682      no       F
# Selfemployeed   14975      yes      F
# Businessman     116246     no       M
# Blue-collar     19999      yes      F
# Govt            45380      yes      M
# Govt            62723      yes      M
# Selfemployeed   36265      no       F
# Retirees        57716      yes      F
# Selfemployeed   14975      yes      F
# Blue-collar     14422      no       F
# Blue-collar     18828      no       F
# Businessman     199268     no       F
# Selfemployeed   37407      no       F
# Selfemployeed   28211      no       F
# Businessman     18856      no       F
# Selfemployeed   2565       yes      F
# Blue-collar     82011      no       M
# Selfemployeed   10461      yes      F
# Selfemployeed   10356      yes      F
# Businessman     21884      no       F
# Selfemployeed   28516      no       F
# White-collar    67575      yes      M
# Retirees        89189      no       M
# Selfemployeed   10250      no       F
# Blue-collar     45818      no       F
# Businessman     112262     no       M
# Businessman     77135      no       M
# Govt            58832      no       M
# Selfemployeed   6550       no       F
# Govt            46221      no       F
# Selfemployeed   26775      yes      F
# Businessman     181977     no       F
# Selfemployeed   14975      no       F
# Govt            35640      yes      F
# Selfemployeed   47690      yes      F
# Businessman     74738      no       M
# Blue-collar     34805      yes      F
# Selfemployeed   55505      yes      M
# Businessman     24964      no       F
# Retirees        65814      no       M
# Govt            47201      no       F
# White-collar    58748      yes      F
# Retirees        15725      yes      F
# Businessman     72387      no       M
# Retirees        66022      no       M
# White-collar    101879     no       M
# Blue-collar     12115      no       F
# Govt            13307      yes      F
# Govt            113730     no       M
# Retirees        30271      yes      F
# Govt            90188      no       M
# Retirees        63492      no       M
# Govt            71624      no       M
# White-collar    61998      yes      M
# Blue-collar     47995      no       F
# White-collar    26660      no       F
# Retirees        66988      no       M
# Selfemployeed   14975      yes      F
# White-collar    45853      yes      M
# White-collar    69459      yes      M
# Selfemployeed   53988      yes      F
# White-collar    53476      no       F
# White-collar    109369     yes      M
# White-collar    108867     no       M
# Businessman     212134     no       F
# Govt            67902      yes      M
# Selfemployeed   11786      no       F
# Blue-collar     114299     no       M
# White-collar    55361      no       F
# Businessman     79751      yes      M
# Retirees        79556      yes      M
# Retirees        15421      no       F
# White-collar    103509     yes      M
# Retirees        65907      no       M
# Selfemployeed   14975      yes      F
# Blue-collar     10594      no       F
# White-collar    73686      yes      M
# Selfemployeed   14975      no       F
# Businessman     212592     yes      M
# Blue-collar     57094      no       F
# Selfemployeed   13030      yes      F
# Selfemployeed   24572      no       F
# Govt            65249      yes      M
# Govt            51839      no       M
# Retirees        28224      yes      F
# Businessman     34181      no       F
# Govt            28428      yes      F
# Businessman     55215      yes      F
# White-collar    48026      no       M
# Selfemployeed   10378      no       F
# Govt            26316      yes      M
# Govt            51912      yes      F
# Businessman     104292     yes      M
# Selfemployeed   14975      yes      F
# Blue-collar     10563      yes      F
# Blue-collar     52355      no       M
# Businessman     158189     yes      M
# Govt            78573      no       M
# White-collar    141877     no       M
# Selfemployeed   65252      yes      M
# Businessman     21805      yes      F
# White-collar    107028     yes      M
# Govt            83828      no       M
# White-collar    66181      yes      M
# Selfemployeed   66976      no       M
# Govt            80939      yes      M
# Businessman     56959      no       F
# Govt            49691      no       M
# White-collar    124133     yes      M
# Businessman     228513     no       F
# Businessman     33522      no       F
# Govt            66306      yes      M
# Blue-collar     27187      no       F
# Selfemployeed   6550       yes      F
# Govt            58855      no       M
# Businessman     183849     no       M
# Businessman     111868     no       M
# Selfemployeed   76624      no       M
# Businessman     105947     no       M
# Businessman     20788      no       F
# Retirees        69682      no       M
# Retirees        27735      yes      F
# Retirees        100075     no       M
# Businessman     54299      no       M
# Blue-collar     92731      no       M
# Blue-collar     114709     yes      M
# Blue-collar     49749      no       F
# Businessman     79634      no       M
# Selfemployeed   14975      yes      F
# Selfemployeed   14975      no       F
# White-collar    99801      yes      M
# Retirees        74142      yes      M
# Govt            21107      no       F
# Retirees        72195      yes      M
# White-collar    48510      no       F
# Blue-collar     23602      no       F
# Retirees        71838      no       M
# Selfemployeed   5525       no       F
# Selfemployeed   14975      yes      F
# Selfemployeed   45802      no       F
# Retirees        76632      no       M
# Blue-collar     53784      yes      F
# Businessman     61639      no       M
# Blue-collar     20204      no       F
# Businessman     53094      yes      M
# Govt            95747      yes      M
# Selfemployeed   8250       no       F
# Selfemployeed   6550       yes      F
# Selfemployeed   7865       yes      F
# Blue-collar     12494      no       F
# Govt            39339      no       F
# Selfemployeed   14975      yes      F
# Blue-collar     42410      no       F
# White-collar    40116      yes      M
# White-collar    58149      no       M
# Govt            104552     yes      M
# White-collar    30786      no       F
# Govt            17285      yes      F
# Selfemployeed   38548      yes      F
# Blue-collar     20787      yes      F
# Govt            54181      no       M
# Selfemployeed   35540      no       F
# Selfemployeed   20071      yes      F
# Selfemployeed   73655      no       M
# Selfemployeed   62287      yes      M
# White-collar    21390      no       F
# Selfemployeed   42187      no       M
# Try another loan status? (Yes/No):  no
# Select an option to filter data:
# 1. Filter by Card Category
# 2. Filter by State
# 3. Filter by Marital Status and Dependents
# 4. Filter by Loan Status and Age
# 0. Quit Program
# Enter your choice (1-4) or '0':  0
# Thank you for using our customer data explorer. Goodbye!

# %%
# ------------------------------
# Task c1: Filter and display data based on card category
# ------------------------------
def filter_by_card_category(csv_list):
    print("\nRetrieve client number, gender, education level, and income based on card category.")
    card_options = {'1': 'BLUE', '2': 'PLATINUM', '3': 'GOLD', '4': 'SILVER'}  # Dictionary of card options

    while True:
        # Display card category options
        print("\nSelect a Card Category:")
        for key, value in card_options.items():
            print(f"{key}. {value.capitalize()}")
        print("0. Quit to Main Menu")

        # Get user input
        user_input = input("Enter your choice (1-4) or '0': ").strip()

        if user_input == '0':  # Return to main menu
            return 'quit'
        if user_input not in card_options:
            print("Invalid option. Try again.")
            continue

        # Filter CSV data based on selected card category
        selected_category = card_options[user_input]
        card_category = []

        for row in csv_list[1:]:  # Skip header row
            if row[15].upper() == selected_category:
                card_category.append([row[0], row[2], row[4], row[13]])

        # Display filtered results
        if card_category:
            print(f"\n{'Client_Num':<12} {'Gender':<8} {'Education_Level':<15} {'Income':<10}")
            print("_" * 45)
            for item in card_category:
                print(f"{item[0]:<12} {item[1]:<8} {item[2]:<15} {item[3]:<10}")
        else:
            print(f"No data found for the category '{selected_category}'.")

        # Ask user if they want to try again
        again = input("\nTry another card category? (Yes/No): ").strip().lower()
        if again != 'yes':
            return

# ------------------------------
# Task c2: Filter and display data based on state
# ------------------------------
def filter_by_state(csv_list):
    print("\nRetrieve the age, gender, income, and credit card category of customers based on state of residence.")

    while True:
        # Prompt for state abbreviation
        print("\nType the State abbreviation (e.g., NY, TX, CA) or '0' to quit to Main Menu.")
        user_input = input("Enter state abbreviation: ").strip().upper()

        if user_input == '0':
            return 'quit'

        state_data = []

        # Filter based on state input
        for row in csv_list[1:]:
            if row[6].upper() == user_input:
                state_data.append([row[1], row[2], row[13], row[15]])

        # Display filtered results
        if state_data:
            print(f"\n{'Customer_Age':<15} {'Gender':<8} {'Income':<10} {'Card_Category':<15}")
            print("-" * 50)
            for item in state_data:
                print(f"{item[0]:<15} {item[1]:<8} {item[2]:<10} {item[3]:<15}")
        else:
            print(f"No data found for state '{user_input}'.")

        # Ask if user wants to continue
        again = input("\nTry another state? (Yes/No): ").strip().lower()
        if again != 'yes':
            return

# ------------------------------
# Task c3: Filter by marital status and number of dependents
# ------------------------------
def filter_by_marital_and_dependents(csv_list):
    print("\nRetrieve age, gender, education level, and job of customers based on marital status and dependents.")

    while True:
        # Marital status options
        marital_options = {'1': 'Single', '2': 'Married', '3': 'Unknown'}
        print("\nSelect Marital Status:")
        for key, value in marital_options.items():
            print(f"{key}. {value}")
        print("0. Quit to Main Menu")

        # User input
        user_input = input("Enter your choice (1-3) or '0': ").strip()

        if user_input == '0':
            return 'quit'
        if user_input not in marital_options:
            print("Invalid option. Try again.")
            continue

        selected_marital = marital_options[user_input]
        marital_status = []

        # Filter based on marital status and dependents > 3
        for row in csv_list[1:]:
            if row[5].lower() == selected_marital.lower() and int(row[3]) > 3:
                marital_status.append([row[1], row[2], row[4], row[12]])

        # Display results
        if marital_status:
            print(f"\n{'Age':<15} {'Gender':<10} {'Education Level':<15} {'Customer Job':<10}")
            print("_" * 55)
            for item in marital_status:
                print(f"{item[0]:<15} {item[1]:<10} {item[2]:<15} {item[3]:<10}")
        else:
            print(f"No data found for marital status '{selected_marital}' with more than 3 dependents.")

        # Ask to retry
        again = input("\nTry another marital status? (Yes/No): ").strip().lower()
        if again != 'yes':
            return
            
# ------------------------------
# Task c4: Filter based on loan status and age above 25
# ------------------------------
def filter_by_loan_and_age(csv_list):
    print("\nRetrieve the job, income, car ownership, and gender of customers older than 25 based on loan status.")

    while True:
        # Loan status options
        loan_options = {'1': 'yes', '2': 'no'}
        print("\nSelect Loan Status:")
        for key, value in loan_options.items():
            print(f"{key}. {value.capitalize()}")
        print("0. Quit to Main Menu")

        # User input
        user_input = input("Enter your choice (1-2) or '0': ").strip()

        if user_input == '0':
            return 'quit'
        if user_input not in loan_options:
            print("Invalid option. Try again.")
            continue

        selected_loan = loan_options[user_input]
        loan_and_gender = []

        # Filter by loan status and age > 25
        for row in csv_list[1:]:
            if row[10].lower() == selected_loan and int(row[1]) > 25:
                loan_and_gender.append([row[12], row[13], row[8], row[2]])

        # Display filtered data
        if loan_and_gender:
            print(f"\n{'Customer_Job':<15} {'Income':<10} {'Car_Owner':<8} {'Gender':<10}")
            print("-" * 45)
            for item in loan_and_gender:
                print(f"{item[0]:<15} {item[1]:<10} {item[2]:<8} {item[3]:<10}")
        else:
            print(f"No data found for loan status '{selected_loan}' and age > 25.")

        # Ask to retry
        again = input("\nTry another loan status? (Yes/No): ").strip().lower()
        if again != 'yes':
            return

# ------------------------------
# Main function to run the program
# ------------------------------
def main():
    csv_list = None  # Initialize CSV list
    while True:
        if csv_list is None:
            csv_list = load_csv_file()  # Load CSV file if not already loaded
            if csv_list is None:
                break  # Exit if file loading was not successful

        # Display main menu
        print("\n=== Credit Card Analysis Menu ===")
        print("1. Filter by Card Category")
        print("2. Filter by State")
        print("3. Filter by Marital Status and Dependents")
        print("4. Filter by Loan Status and Age")
        print("0. Quit Program")

        choice = input("Enter your choice (1-4) or '0': ").strip()

        # Map choice to appropriate function
        if choice == '1':
            result = filter_by_card_category(csv_list)
        elif choice == '2':
            result = filter_by_state(csv_list)
        elif choice == '3':
            result = filter_by_marital_and_dependents(csv_list)
        elif choice == '4':
            result = filter_by_loan_and_age(csv_list)
        elif choice == '0':
            print("\nThank you for using our customer data explorer. Goodbye!")
            break  # End program
        else:
            print("Invalid choice. Please try again.")
            continue

        # Return to main menu if user chooses to quit within a filter
        if result == 'quit':
            print("Returning to main menu.\n")

# ------------------------------
# Entry point of the program
# ------------------------------
if __name__ == "__main__":
    main()
# Out:
# Enter the CSV file name or enter 'q' to quit the program:  credit_card_customers.csv
# CSV file loaded successfully.
#
# === Credit Card Analysis Menu ===
# 1. Filter by Card Category
# 2. Filter by State
# 3. Filter by Marital Status and Dependents
# 4. Filter by Loan Status and Age
# 0. Quit Program
# Enter your choice (1-4) or '0':  0
# Thank you for using our customer data explorer. Goodbye!
